# %%
import pandas as pd
import glob
import re

# %%
files = glob.glob("../raw_data/*")

# %% [markdown]
# # indicators

# %%
# when multiple gnd_ids appear in one line (connected with '+'), split them in multiple lines
def expand_multiple_ids(df, column='GND'):
    new_rows_list = []
    rows_to_drop = []

    rows_with_plus = df[df[column].str.contains(r'\+', na=False)]

    for index, row in rows_with_plus.iterrows():
        gnd_ids = row[column].split(' + ')
        rows_to_drop.append(index)
        for gnd_id in gnd_ids:
            new_row = row.copy()
            new_row[column] = gnd_id
            new_rows_list.append(new_row)

    if new_rows_list:
        new_rows_df = pd.DataFrame(new_rows_list)
        df = df.drop(rows_to_drop)
        df = pd.concat([df, new_rows_df], ignore_index=True)
    
    return df

# %% [markdown]
# ## unilist

# %%
unilist_files = [x for x in files if 'unilist' in x]

# %%
# prepare individual unilists
unilists = {}

for this_file in unilist_files:
    unilist_name = this_file.split("/")[-1].split(".")[0]
    unilist_df = pd.read_csv(this_file)
    unilist_df = expand_multiple_ids(unilist_df)
    unilist_df = unilist_df[~unilist_df['author'].str.startswith('$', na = False)] # filter editors
    unilist_df = unilist_df.groupby(['GND'], as_index=False)['prob_to_read'].sum()
    unilist_df = unilist_df.rename(columns={'prob_to_read' : 'prob_to_read_sum_'+unilist_name})
    unilist_df['prob_to_read_share_'+unilist_name] = unilist_df['prob_to_read_sum_'+unilist_name]/unilist_df['prob_to_read_sum_'+unilist_name].sum()
    
    unilists[unilist_name] = unilist_df

# %%
# merge unilists
unilist_iter = iter(unilists.items())
first_name, unilist_merged = next(unilist_iter)

for unilist_name, unilist_df in unilist_iter:
    unilist_merged = pd.merge(
        unilist_merged,
        unilist_df,
        on='GND',
        how='outer',
    )
unilist_merged = unilist_merged.fillna(0).reset_index(drop=True)

# %%
unilist_merged.sort_values(by='prob_to_read_sum_unilist_goettingen', ascending=False)
# Out:
#             GND  prob_to_read_sum_unilist_heidelberg_2017  \
# 200   118540238                                  5.727273
# 434   118607626                                  3.636364
# 304   118563076                                  3.764706
# 356   118577166                                  1.194805
# 890   12989432X                                  1.000000
# ..          ...                                       ...
# 908   138119813                                  0.000000
# 909   14009931X                                  0.000000
# 910   140917462                                  0.000000
# 911   141869674                                  0.000000
# 4    1070181080                                  0.000000
#
#      prob_to_read_share_unilist_heidelberg_2017  \
# 200                                    0.086515
# 434                                    0.054930
# 304                                    0.056869
# 356                                    0.018048
# 890                                    0.015106
# ..                                          ...
# 908                                    0.000000
# 909                                    0.000000
# 910                                    0.000000
# 911                                    0.000000
# 4                                      0.000000
#
#      prob_to_read_sum_unilist_aachen_201718  \
# 200                                2.492755
# 434                                2.216484
# 304                                0.663836
# 356                                0.176000
# 890                                0.213287
# ..                                      ...
# 908                                0.000000
# 909                                0.000000
# 910                                0.000000
# 911                                0.000000
# 4                                  0.000000
#
#      prob_to_read_share_unilist_aachen_201718  \
# 200                                  0.040582
# 434                                  0.036084
# 304                                  0.010807
# 356                                  0.002865
# 890                                  0.003472
# ..                                        ...
# 908                                  0.000000
# 909                                  0.000000
# 910                                  0.000000
# 911                                  0.000000
# 4                                    0.000000
#
#      prob_to_read_sum_unilist_goettingen  \
# 200                             6.000000
# 434                             3.333333
# 304                             3.000000
# 356                             3.000000
# 890                             2.000000
# ..                                   ...
# 908                             0.000000
# 909                             0.000000
# 910                             0.000000
# 911                             0.000000
# 4                               0.000000
#
#      prob_to_read_share_unilist_goettingen  \
# 200                               0.093750
# 434                               0.052083
# 304                               0.046875
# 356                               0.046875
# 890                               0.031250
# ..                                     ...
# 908                               0.000000
# 909                               0.000000
# 910                               0.000000
# 911                               0.000000
# 4                                 0.000000
#
#      prob_to_read_sum_unilist_luxemburg  prob_to_read_share_unilist_luxemburg  \
# 200                                 7.0                              0.097222
# 434                                 3.0                              0.041667
# 304                                 2.0                              0.027778
# 356                                 1.0                              0.013889
# 890                                 2.0                              0.027778
# ..                                  ...                                   ...
# 908                                 0.0                              0.000000
# 909                                 0.0                              0.000000
# 910                                 1.0                              0.013889
# 911                                 0.0                              0.000000
# 4                                   0.0                              0.000000
#
#      prob_to_read_sum_unilist_graz_2021  ...  \
# 200                                 4.0  ...
# 434                                 2.0  ...
# 304                                 1.0  ...
# 356                                 1.0  ...
# 890                                 0.0  ...
# ..                                  ...  ...
# 908                                 0.0  ...
# 909                                 0.0  ...
# 910                                 0.0  ...
# 911                                 0.0  ...
# 4                                   0.0  ...
#
#      prob_to_read_sum_unilist_innsbruck  prob_to_read_share_unilist_innsbruck  \
# 200                                 3.0                              0.081081
# 434                                 3.0                              0.081081
# 304                                 1.0                              0.027027
# 356                                 1.0                              0.027027
# 890                                 0.0                              0.000000
# ..                                  ...                                   ...
# 908                                 0.0                              0.000000
# 909                                 0.0                              0.000000
# 910                                 0.0                              0.000000
# 911                                 0.0                              0.000000
# 4                                   0.0                              0.000000
#
#      prob_to_read_sum_unilist_osnabrueck  \
# 200                             2.500000
# 434                             1.250000
# 304                             1.250000
# 356                             0.833333
# 890                             0.000000
# ..                                   ...
# 908                             0.000000
# 909                             0.000000
# 910                             0.000000
# 911                             0.000000
# 4                               0.000000
#
#      prob_to_read_share_unilist_osnabrueck  \
# 200                               0.051282
# 434                               0.025641
# 304                               0.025641
# 356                               0.017094
# 890                               0.000000
# ..                                     ...
# 908                               0.000000
# 909                               0.000000
# 910                               0.000000
# 911                               0.000000
# 4                                 0.000000
#
#      prob_to_read_sum_unilist_la_aachen_2018  \
# 200                                 1.500000
# 434                                 0.845000
# 304                                 0.819000
# 356                                 0.076923
# 890                                 0.292000
# ..                                       ...
# 908                                 0.000000
# 909                                 0.000000
# 910                                 0.000000
# 911                                 0.000000
# 4                                   0.000000
#
#      prob_to_read_share_unilist_la_aachen_2018  \
# 200                                   0.060549
# 434                                   0.034109
# 304                                   0.033060
# 356                                   0.003105
# 890                                   0.011787
# ..                                         ...
# 908                                   0.000000
# 909                                   0.000000
# 910                                   0.000000
# 911                                   0.000000
# 4                                     0.000000
#
#      prob_to_read_sum_unilist_fu_berlin  prob_to_read_share_unilist_fu_berlin  \
# 200                                13.0                              0.050000
# 434                                10.0                              0.038462
# 304                                 7.0                              0.026923
# 356                                 6.0                              0.023077
# 890                                 2.0                              0.007692
# ..                                  ...                                   ...
# 908                                 0.0                              0.000000
# 909                                 0.0                              0.000000
# 910                                 0.0                              0.000000
# 911                                 0.0                              0.000000
# 4                                   0.0                              0.000000
#
#      prob_to_read_sum_unilist_zuerich_2013  \
# 200                                    9.0
# 434                                    6.0
# 304                                    4.0
# 356                                    5.0
# 890                                    0.0
# ..                                     ...
# 908                                    0.0
# 909                                    0.0
# 910                                    0.0
# 911                                    0.0
# 4                                      0.0
#
#      prob_to_read_share_unilist_zuerich_2013
# 200                                 0.037190
# 434                                 0.024793
# 304                                 0.016529
# 356                                 0.020661
# 890                                 0.000000
# ..                                       ...
# 908                                 0.000000
# 909                                 0.000000
# 910                                 0.000000
# 911                                 0.000000
# 4                                   0.000000
#
# [913 rows x 85 columns]

# %% [markdown]
# ## litges

# %%
brenner = pd.read_csv("../raw_data/litges_brenner.csv", sep=";", index_col=[0])
brenner = brenner[['GND-Nummer', 'Anzahl_Seiten_neu']]
brenner = brenner.rename(columns={'GND-Nummer' : 'GND', 'Anzahl_Seiten_neu' : 'page_count'})
brenner['page_count_rel'] = brenner['page_count']/369
brenner = brenner.query("GND.notna()")

# %%
beutin = pd.read_csv("../raw_data/litges_beutin.csv", sep=";", index_col=[0])
beutin = beutin.query("ignore.isna()")
beutin = beutin[['GND-Nummer', 'Anzahl_Seiten_neu']]
beutin = beutin.rename(columns={'GND-Nummer' : 'GND', 'Anzahl_Seiten_neu' : 'page_count'})
beutin['page_count_rel'] = beutin['page_count']/758
beutin = beutin.query("GND.notna()")

# %%
litges_merged = pd.merge(
        beutin,
        brenner,
        on='GND',
        how='outer',
        suffixes=['_litges_beutin', '_litges_brenner']
    )
litges_merged = litges_merged.fillna(0).reset_index(drop=True)

# %%
litges_merged.sort_values(by='page_count_litges_brenner', ascending=False)
# Out:
#             GND  page_count_litges_beutin  page_count_rel_litges_beutin  \
# 455   118540238                      62.0                      0.081794
# 731   118577166                      27.0                      0.035620
# 275   118514768                      98.0                      0.129288
# 918   118607626                      52.0                      0.068602
# 1083  118632477                      11.0                      0.014512
# ...         ...                       ...                           ...
# 1803  13213523X                       1.0                      0.001319
# 1804  132139901                       1.0                      0.001319
# 1808  132721392                       1.0                      0.001319
# 1809  135697042                       1.0                      0.001319
# 1810  135891388                       1.0                      0.001319
#
#       page_count_litges_brenner  page_count_rel_litges_brenner
# 455                        27.0                       0.073171
# 731                        24.0                       0.065041
# 275                        19.0                       0.051491
# 918                        18.0                       0.048780
# 1083                       15.0                       0.040650
# ...                         ...                            ...
# 1803                        0.0                       0.000000
# 1804                        0.0                       0.000000
# 1808                        0.0                       0.000000
# 1809                        0.0                       0.000000
# 1810                        0.0                       0.000000
#
# [1825 rows x 5 columns]

# %% [markdown]
# ## vv

# %%
vv_mainz_raw = pd.read_csv("../raw_data/vv_mainz.csv", sep=";", index_col=[0])
vv_mainz_event_count = 213 # vv_mainz_raw['ID'].nunique()
vv_mainz_raw = vv_mainz_raw.query("wrong_mention.isna() and GND_ID != 'no_ID' and GND_ID.notna()")

vv_mainz = pd.DataFrame()
for gnd_id in vv_mainz_raw['GND_ID'].unique():
    this_id_event_count = vv_mainz_raw.query("GND_ID==@gnd_id")['ID'].nunique()
    vv_mainz.at[gnd_id, 'event_count_vv_mainz'] = this_id_event_count
    vv_mainz.at[gnd_id, 'event_count_rel_vv_mainz'] = this_id_event_count/vv_mainz_event_count
vv_mainz = vv_mainz.reset_index(names='GND')

# %%
vv_stuttgart_raw = pd.read_csv("../raw_data/vv_stuttgart.csv", sep=";", index_col=[0])
vv_stuttgart_event_count = 491 # vv_stuttgart_raw['ID'].nunique()
vv_stuttgart_raw = vv_stuttgart_raw.query("wrong_mention.isna() and GND_ID != 'no_ID' and GND_ID.notna()")

vv_stuttgart = pd.DataFrame()
for gnd_id in vv_stuttgart_raw['GND_ID'].unique():
    this_id_event_count = vv_stuttgart_raw.query("GND_ID==@gnd_id")['ID'].nunique()
    vv_stuttgart.at[gnd_id, 'event_count_vv_stuttgart'] = this_id_event_count
    vv_stuttgart.at[gnd_id, 'event_count_rel_vv_stuttgart'] = this_id_event_count/vv_stuttgart_event_count
vv_stuttgart = vv_stuttgart.reset_index(names='GND')

# %%
vv_wien_raw = pd.read_csv("../raw_data/vv_wien.csv", sep=";", index_col=[0])
vv_wien_event_count = 203 # vv_wien_raw['ID'].nunique()
vv_wien_raw = vv_wien_raw.query("wrong_mention.isna() and GND_ID != 'no_ID' and GND_ID.notna()")

vv_wien = pd.DataFrame()
for gnd_id in vv_wien_raw['GND_ID'].unique():
    this_id_event_count = vv_wien_raw.query("GND_ID==@gnd_id")['ID'].nunique()
    vv_wien.at[gnd_id, 'event_count_vv_wien'] = this_id_event_count
    vv_wien.at[gnd_id, 'event_count_rel_vv_wien'] = this_id_event_count/vv_wien_event_count
vv_wien = vv_wien.reset_index(names='GND')

# %%
vv_merged = pd.merge(
        vv_mainz,
        vv_stuttgart,
        on='GND',
        how='outer',
    ).merge(
        vv_wien,
        on='GND',
        how='outer',
    )
vv_merged = vv_merged.fillna(0)
vv_merged = vv_merged.query("GND.str.contains('-') == False and GND.str.contains(' ') == False")
vv_merged = vv_merged.reset_index(drop=True)

# %%
vv_merged.sort_values(by='event_count_vv_stuttgart', ascending=False)
# Out:
#             GND  event_count_vv_mainz  event_count_rel_vv_mainz  \
# 319   118540238                  16.0                  0.075117
# 520   118607626                   8.0                  0.037559
# 391   118559230                   4.0                  0.018779
# 408   118563076                   7.0                  0.032864
# 361   118552465                   5.0                  0.023474
# ...         ...                   ...                       ...
# 1015  136500757                   0.0                  0.000000
# 581   118627724                   0.0                  0.000000
# 582   118628097                   2.0                  0.009390
# 585   118629867                   7.0                  0.032864
# 588   118630822                   0.0                  0.000000
#
#       event_count_vv_stuttgart  event_count_rel_vv_stuttgart  \
# 319                       36.0                      0.073320
# 520                       22.0                      0.044807
# 391                       18.0                      0.036660
# 408                       14.0                      0.028513
# 361                       14.0                      0.028513
# ...                        ...                           ...
# 1015                       0.0                      0.000000
# 581                        0.0                      0.000000
# 582                        0.0                      0.000000
# 585                        0.0                      0.000000
# 588                        0.0                      0.000000
#
#       event_count_vv_wien  event_count_rel_vv_wien
# 319                  12.0                 0.059113
# 520                   5.0                 0.024631
# 391                  12.0                 0.059113
# 408                   5.0                 0.024631
# 361                   5.0                 0.024631
# ...                   ...                      ...
# 1015                  2.0                 0.009852
# 581                   1.0                 0.004926
# 582                   0.0                 0.000000
# 585                   0.0                 0.000000
# 588                   1.0                 0.004926
#
# [1060 rows x 7 columns]

# %% [markdown]
# ## lexika

# %%
killy = pd.read_csv("../raw_data/killy.csv", sep=";")
killy = killy[['GND', 'length']]
killy = killy.query("GND.notna() and length.notna()")
killy = killy.rename(columns={'length':'killy_length'})
killy = killy.groupby('GND')['killy_length'].sum().to_frame().reset_index() # handle 116720964

# %%
killy.sort_values(by='killy_length', ascending=False)
# Out:
#              GND  killy_length
# 2760   118540238       10344.0
# 3532   118607626        8717.0
# 2497   118514768        7449.0
# 2935   118551981        7248.0
# 3695   11862220X        7172.0
# ...          ...           ...
# 6774   127465235         175.0
# 4983   118833340         174.0
# 589   1043512810         169.0
# 1831   116922842         165.0
# 6587   124300251         145.0
#
# [7235 rows x 2 columns]

# %% [markdown]
# ## editions

# %%
reclam = pd.read_csv("../raw_data/reclam.csv")
reclam = expand_multiple_ids(reclam, column='GND_author')
reclam = reclam.query("GND_author.notna()")

# %%
sachgruppen = reclam['sachgruppen'].tolist()
sachgruppen = [item for sublist in [str(x).split(" + ") for x in sachgruppen] for item in sublist]
pd.Series(sachgruppen).value_counts().index.tolist()
# Out:
# ['59 Belletristik',
#  'B Belletristik',
#  '830 Deutsche Literatur',
#  '10 Philosophie',
#  '100 Philosophie',
#  '63 Geschichte und Historische Hilfswissenschaften',
#  '53 Deutsche Sprach- und Literaturwissenschaft',
#  'nan',
#  'S Schulbücher',
#  '820 Englische Literatur',
#  '420 Englisch',
#  '49 Theater, Tanz, Film',
#  '840 Französische Literatur',
#  '08a Schöne Literatur',
#  '440 Französisch, romanische Sprachen allgemein',
#  '48 Musik',
#  '780 Musik',
#  '870 Lateinische Literatur',
#  '12 Christliche Religion',
#  '16 Politik',
#  '51 Allgemeine und Vergleichende Sprach- und Literaturwissenschaft',
#  '56 Klassische Sprach- und Literaturwissenschaft',
#  '810 Englische Literatur Amerikas',
#  '930 Alte Geschichte, Archäologie',
#  '880 Griechische Literatur',
#  '891.8 Slawische Literatur',
#  '940 Geschichte Europas',
#  '320 Politik',
#  '230 Theologie, Christentum',
#  '300 Sozialwissenschaften, Soziologie, Anthropologie',
#  '19 Recht',
#  '720 Architektur',
#  '23 Schulbücher',
#  '01 Wissenschaft und Kultur allgemein',
#  '13 Allgemeine und Vergleichende Religionswissenschaft, Nichtchristliche Religionen',
#  '700 Künste, Bildende Kunst allgemein',
#  '11 Psychologie',
#  '460 Spanisch, Portugiesisch',
#  '14 Soziologie, Gesellschaft',
#  '13x Textbücher',
#  '839 Literatur in anderen germanischen Sprachen',
#  '860 Spanische und portugiesische Literatur',
#  '46 Bildende Kunst',
#  '03 Nachschlagewerke, Bibliographien',
#  '450 Italienisch, Rumänisch, Rätoromanisch',
#  '2303 Belletristik',
#  '61 Geographie, Heimat- und Länderkunde, Reisen',
#  '850 Italienische, rumänische, rätoromanische Literatur',
#  '150 Psychologie',
#  '800 Literatur, Rhetorik, Literaturwissenschaft',
#  '943 Geschichte Deutschlands',
#  '290 Andere Religionen',
#  '55 Romanische Sprach- und Literaturwissenschaft',
#  '64 Sozialgeschichte',
#  '26 Natur, Naturwissenschaften allgemein',
#  '52 Englische Sprach- und Literaturwissenschaft',
#  '21 Militär',
#  '200 Religion, Religionsphilosophie',
#  '12a Bildende Kunst, Kunstgewerbe',
#  '370 Erziehung, Schul- und Bildungswesen',
#  '900 Geschichte',
#  '330 Wirtschaft',
#  '950 Geschichte Asiens',
#  '430 Deutsch',
#  '470 Latein',
#  '340 Recht',
#  '22 Erziehung, Bildung, Unterricht',
#  '57 Slawische und baltische Sprach- und Literaturwissenschaft',
#  '32 Biologie',
#  '07 Kinder- und Jugendliteratur',
#  '390 Bräuche, Etikette, Folklore',
#  '03a Philosophie',
#  '33 Medizin',
#  '610 Medizin, Gesundheit',
#  '220 Bibel',
#  '29 Physik, Astronomie',
#  '890 Literatur in anderen Sprachen',
#  '400 Sprache, Linguistik',
#  '970 Geschichte Nordamerikas',
#  '004 Informatik',
#  '530 Physik',
#  '490 Andere Sprachen',
#  '60 Archäologie, Vor- und Frühgeschichte',
#  '792 Theater, Tanz',
#  '740 Grafik, angewandte Kunst',
#  '07a Sprach- und Literaturwissenschaft',
#  '750 Malerei',
#  '25 Volkskunde, Völkerkunde',
#  'K Kinder- und Jugendliteratur',
#  '27 Mathematik',
#  '45 Architektur',
#  '000 Allgemeines, Wissenschaft',
#  '08 Comics, Cartoons, Karikaturen',
#  '491.8 Slawische Sprachen',
#  '640 Hauswirtschaft und Familienleben',
#  '02 Schrift, Buch, Bibliothek, Information und Dokumentation',
#  '355 Militär',
#  '40 Hauswirtschaft, Kochen, Hotel- und Gaststättengewerbe',
#  '06 Publizistik',
#  '44 Umweltschutz, Raumordnung, Landschaftsgestaltung',
#  '39 Landwirtschaft, Garten',
#  '791 Öffentliche Darbietungen, Film, Rundfunk',
#  '510 Mathematik',
#  '793 Spiel',
#  '500 Naturwissenschaften',
#  '14a Geschichte, Kulturgeschichte, Volkskunde',
#  '360 Soziale Probleme, Sozialdienste, Versicherungen',
#  '17 Wirtschaft',
#  '50 Sport, Spiele',
#  '09 Grenzgebiete der Wissenschaft und Esoterik',
#  '65 Wirtschaftsgeschichte',
#  '28 Informatik, Datenverarbeitung',
#  '620 Ingenieurwissenschaften und Maschinenbau',
#  '333.7 Natürliche Ressourcen, Energie und Umwelt',
#  '910 Geografie, Reisen',
#  '02a Religion, Theologie',
#  '730 Plastik, Numismatik, Keramik, Metallkunst',
#  '58 Sprach- und Literaturwissenschaft sonstiger Sprachen',
#  '35 Technik allgemein',
#  '130 Parapsychologie, Okkultismus',
#  '741.5 Comics, Cartoons, Karikaturen',
#  '650 Management',
#  '080 Allgemeine Sammelwerke',
#  '2600 Philosophische Wissenschaften, Psychologie',
#  '590 Tiere (Zoologie)',
#  '920 Biografie, Genealogie, Heraldik',
#  '79 Berichtigungen',
#  '520 Astronomie, Kartographie',
#  '621.3 Elektrotechnik, Elektronik',
#  '06a Politik, Wehrwesen',
#  '05b Sozialwissenschaften',
#  '914.3 Geografie, Reisen (Deutschland)',
#  '770 Fotografie, Video, Computerkunst',
#  '0100 Klassiker des Marxismus; Allgemeine Werke zum Marxismus-Leninismus',
#  '980 Geschichte Südamerikas',
#  '03b Psychologie',
#  '42 Technische Chemie, Lebensmitteltechnologie, Textiltechnik und andere Technologien',
#  '760 Druckgrafik, Drucke',
#  '710 Landschaftsgestaltung, Raumplanung',
#  '630 Landwirtschaft, Veterinärmedizin',
#  '960 Geschichte Afrikas',
#  '13a Musik, Tanz, Theater, Film, Rundfunk',
#  '570 Biowissenschaften, Biologie',
#  '090 Handschriften, seltene Bücher',
#  '020 Bibliotheks- und Informationswissenschaft',
#  '380 Handel, Kommunikation, Verkehr',
#  '560 Paläontologie',
#  '010 Bibliografien',
#  '54 Sprach- und Literaturwissenschaft der übrigen germanischen Sprachen',
#  '600 Technik',
#  '070 Nachrichtenmedien, Journalismus, Verlagswesen',
#  '18 Arbeit',
#  '47 Photographie',
#  'B:420',
#  '796 Sport',
#  '2301 Sprachwissenschaften',
#  '550 Geowissenschaften',
#  '01a Allgemeines, Hochschulen',
#  '2302 Literaturwissenschaften',
#  '660 Technische Chemie',
#  '580 Pflanzen (Botanik)',
#  '030 Enzyklopädien',
#  '2600 Philosophische Wissenschaften, Psychologie ',
#  '04a Recht, Verwaltung',
#  '17a Medizin',
#  '2000 Staat und Recht, Rechtswissenschaften',
#  '2402 Musik, Theater, Tanz, Film']

# %%
# filter already at this point, because we want to calc the appropriate reclam_count
# but do not filter sachgruppen
relevant_sachgruppen = [
    '59 Belletristik', 'B Belletristik', '830 Deutsche Literatur',
    '08a Schöne Literatur', '2303 Belletristik', '800 Literatur, Rhetorik, Literaturwissenschaft',
    'K Kinder- und Jugendliteratur', '08 Comics, Cartoons, Karikaturen',
    '741.5 Comics, Cartoons, Karikaturen'
]

reclam = (
    reclam
    .query("year >= 2000")
    # .loc[reclam['sachgruppen'].str.contains('|'.join(relevant_sachgruppen), na=False)]
)

# %%
reclam = reclam['GND_author'].value_counts().to_frame().reset_index()
reclam = reclam.rename(columns={'GND_author' : 'GND', 'count' : 'reclam_count'})

# %%
reclam
# Out:
#             GND  reclam_count
# 0     118613723            75
# 1     118540238            63
# 2     118607626            51
# 3     118520814            44
# 4     128451661            41
# ...         ...           ...
# 1459  131495879             1
# 1460  124300812             1
# 1461  115738290             1
# 1462  120283743             1
# 1463  119273845             1
#
# [1464 rows x 2 columns]

# %% [markdown]
# ## bibliographies

# %%
bdsl = pd.read_csv("../raw_data/bdsl.csv", index_col=[0])
bdsl = bdsl.rename(columns={'searchphrase' : 'BDSL_searchphrase'})

# %%
bdsl.sort_values(by='BDSL_hits_2000_all', ascending=False).head(200).values
# Out:
# array([['116804521', 'Friedrich Friedrich', 18253.0],
#        ['137325355', 'Heinrich', 12137.0],
#        ['118540238', 'Johann Wolfgang von Goethe', 10227.0],
#        ['1016491166', 'L. A. Paul', 8242.0],
#        ['118559230', 'Franz Kafka', 4864.0],
#        ['118577166', 'Thomas Mann', 4798.0],
#        ['118607626', 'Friedrich Schiller', 3890.0],
#        ['118563076', 'Heinrich von Kleist', 3334.0],
#        ['118587943', 'Friedrich Nietzsche', 3296.0],
#        ['118514768', 'Bertolt Brecht', 3179.0],
#        ['118558749', 'C. G. Jung', 3155.0],
#        ['118552465', 'E. T. A. Hoffmann', 3016.0],
#        ['118509039', 'Walter Benjamin', 2951.0],
#        ['1178632180', 'O.F. Berg', 2728.0],
#        ['118548018', 'Heinrich Heine', 2460.0],
#        ['1112471774', 'Albrecht', 2456.0],
#        ['118534262', 'Theodor Fontane', 2380.0],
#        ['118601024', 'Rainer Maria Rilke', 2322.0],
#        ['118519859', 'Paul Celan', 2287.0],
#        ['118551981', 'Friedrich Hölderlin', 2137.0],
#        ['118818651', 'Karl May', 1883.0],
#        ['118594117', 'Richard Wagner', 1747.0],
#        ['122541332', 'Richard Wagner', 1747.0],
#        ['118572121', 'Gotthold Ephraim Lessing', 1723.0],
#        ['118585916', 'Robert Musil', 1689.0],
#        ['118541579', 'Günter Grass', 1685.0],
#        ['118581783', 'E. Y. Meyer', 1604.0],
#        ['118505602', 'Ingeborg Bachmann', 1557.0],
#        ['119001802', 'Elfriede Jelinek', 1516.0],
#        ['118509861', 'Thomas Bernhard', 1498.0],
#        ['119310007', 'W. G. Sebald', 1488.0],
#        ['118552759', 'Hugo von Hofmannsthal', 1441.0],
#        ['118558587', 'Ernst Jünger', 1428.0],
#        ['118549553', 'Johann Gottfried von Herder', 1406.0],
#        ['11855042X', 'Hermann Hesse', 1374.0],
#        ['118618156', 'Adalbert Stifter', 1280.0],
#        ['118545574', 'Peter Handke', 1226.0],
#        ['118609807', 'Arthur Schnitzler', 1168.0],
#        ['118634674', 'Friedrich Wolf', 1164.0],
#        ['118557211', 'Jean Paul', 1154.0],
#        ['118516906', 'Georg Büchner', 1152.0],
#        ['118500775', 'Theodor W. Adorno', 1085.0],
#        ['118608703', 'Arno Schmidt', 1078.0],
#        ['118634933', 'von Eschenbach Wolfram', 1068.0],
#        ['120404389', 'P. D. James', 1060.0],
#        ['118637479', 'Stefan Zweig', 1052.0],
#        ['118634666', 'Christa Wolf', 1043.0],
#        ['118526200', 'Alfred Döblin', 1038.0],
#        ['118588893', 'Novalis', 1024.0],
#        ['118577131', 'Heinrich Mann', 1009.0],
#        ['119403412', 'E. A. Richter', 981.0],
#        ['118618725', 'Theodor Storm', 951.0],
#        ['118547798', 'Martin Heidegger', 950.0],
#        ['118628860', 'Robert Walser', 944.0],
#        ['118575449', 'Martin Luther', 924.0],
#        ['11853856X', 'Stefan George', 918.0],
#        ['118509047', 'Gottfried Benn', 884.0],
#        ['118584944', 'Heiner Müller', 883.0],
#        ['118603140', 'Joseph Roth', 842.0],
#        ['118542249', 'Hans Grimm', 840.0],
#        ['118612743', 'Anna Seghers', 835.0],
#        ['118559796', 'Immanuel Kant', 811.0],
#        ['118518801', 'Elias Canetti', 810.0],
#        ['118632477', 'Christoph Martin Wieland', 808.0],
#        ['118546937', 'Gerhart Hauptmann', 788.0],
#        ['118535315', 'Sigmund Freud', 785.0],
#        ['118515551', 'Hermann Broch', 762.0],
#        ['118607987', 'Friedrich von Schlegel', 762.0],
#        ['128822724', 'D. B. C. Pierre', 759.0],
#        ['11856109X', 'Gottfried Keller', 755.0],
#        ['118546228', 'von Aue Hartmann', 751.0],
#        ['11855817X', 'Uwe Johnson', 734.0],
#        ['11850391X', 'Hannah Arendt', 722.0],
#        ['118542273', 'Hans Jakob Christoffel von Grimmelshausen', 720.0],
#        ['118566288', 'Karl Kraus', 701.0],
#        ['118597442', 'Wilhelm Raabe', 700.0],
#        ['118536109', 'Max Frisch', 684.0],
#        ['118527908', 'Friedrich Dürrenmatt', 669.0],
#        ['118529390', 'Joseph von Eichendorff', 666.0],
#        ['119053071', 'Herta Müller', 658.0],
#        ['118630539', 'Peter Weiss', 636.0],
#        ['118542257', 'Jacob Grimm', 630.0],
#        ['118547739', 'Georg Wilhelm Friedrich Hegel', 626.0],
#        ['118628852', 'Martin Walser', 611.0],
#        ['12989432X', 'Ludwig Tieck', 580.0],
#        ['118512676', 'Heinrich Böll', 565.0],
#        ['118613723', 'William Shakespeare', 563.0],
#        ['118534408', 'E. M. Forster', 560.0],
#        ['118527533', 'Annette von Droste-Hülshoff', 557.0],
#        ['118625756', 'Johann Peter Uz', 549.0],
#        ['118540947', 'von Straßburg Gottfried', 540.0],
#        ['128881526', 'Michael Braun', 533.0],
#        ['118559206', 'Erich Kästner', 530.0],
#        ['118515055', 'Clemens Brentano', 518.0],
#        ['118571656', 'Jakob Michael Reinhold Lenz', 506.0],
#        ['120878518', 'Yōko Tawada', 499.0],
#        ['118542265', 'Wilhelm Grimm', 498.0],
#        ['118587080', 'Johann Nestroy', 497.0],
#        ['118534424', 'Georg Forster', 491.0],
#        ['118534416', 'Georg Forster', 491.0],
#        ['118542192', 'Franz Grillparzer', 482.0],
#        ['118569880', 'Else Lasker-Schüler', 478.0],
#        ['118572628', 'Georg Christoph Lichtenberg', 475.0],
#        ['119545780', 'F. Zell', 467.0],
#        ['118623575', 'Georg Trakl', 465.0],
#        ['120013428', 'Christian Kracht', 465.0],
#        ['118544330', 'Peter Hacks', 465.0],
#        ['118504177', 'Achim von Arnim', 457.0],
#        ['1083009273', 'Brüder Grimm', 455.0],
#        ['118599631', 'Erich Maria Remarque', 451.0],
#        ['118584162', 'Karl Philipp Moritz', 451.0],
#        ['118563491', 'Alexander Kluge', 449.0],
#        ['118564471', 'Wolfgang Koeppen', 448.0],
#        ['118934163', 'Bai Li', 447.0],
#        ['118840991', 'Christoph Hein', 445.0],
#        ['118956299', 'Christoph Ransmayr', 443.0],
#        ['118839276', 'Uwe Timm', 436.0],
#        ['118547445', 'Friedrich Hebbel', 431.0],
#        ['118634313', 'Ludwig Wittgenstein', 429.0],
#        ['118628976', 'von der Vogelweide Walther', 418.0],
#        ['118528823', 'Meister Eckhart', 417.0],
#        ['11855249X', 'Heinrich Hoffmann', 412.0],
#        ['118577158', 'Klaus Mann', 412.0],
#        ['118530534', 'Hans Magnus Enzensberger', 401.0],
#        ['118500708', 'H. G. Adler', 398.0],
#        ['119371391', 'Durs Grünbein', 397.0],
#        ['118554727', 'Wilhelm von Humboldt', 394.0],
#        ['118583107', 'Eduard Mörike', 379.0],
#        ['118501232', 'Ilse Aichinger', 372.0],
#        ['118526162', 'Heimito von Doderer', 371.0],
#        ['118565877', 'Siegfried Kracauer', 370.0],
#        ['115812431', 'Daniel Kehlmann', 360.0],
#        ['118504185', 'Bettina von Arnim', 360.0],
#        ['118535897', 'Ernst Friedrich', 353.0],
#        ['118841386', 'Wu Sun', 347.0],
#        ['118580744', 'Moses Mendelssohn', 342.0],
#        ['118599194', 'Marcel Reich-Ranicki', 336.0],
#        ['119406586', 'Emine Sevgi Özdamar', 332.0],
#        ['118732404', 'Friederike Mayröcker', 331.0],
#        ['118610465', 'Arthur Schopenhauer', 329.0],
#        ['11857518X', 'Georg Lukács', 323.0],
#        ['123120802', 'Juli Zeh', 322.0],
#        ['118554700', 'Alexander von Humboldt', 314.0],
#        ['124138004', 'Johann Georg Hamann', 311.0],
#        ['118553739', 'Ödön von Horváth', 311.0],
#        ['11854523X', 'Johann Georg Hamann', 311.0],
#        ['118829211', 'Rose Ausländer', 310.0],
#        ['118532715', 'Lion Feuchtwanger', 310.0],
#        ['118530666', 'Desiderius Erasmus', 309.0],
#        ['118514644', 'Volker Braun', 308.0],
#        ['118619047', 'Botho Strauß', 308.0],
#        ['119076993', 'Wolfgang Hilbig', 307.0],
#        ['118561359', 'Walter Kempowski', 301.0],
#        ['121531287', 'Ritchie Robertson', 300.0],
#        ['118556894', 'Ernst Jandl', 300.0],
#        ['118590618', 'von Wolkenstein Oswald', 299.0],
#        ['116067624', 'H. W. Katz', 298.0],
#        ['118631373', 'Franz Werfel', 297.0],
#        ['120309297', 'Heinrich Detering', 297.0],
#        ['118515470', 'Rolf Dieter Brinkmann', 297.0],
#        ['118502549', 'Jean Améry', 296.0],
#        ['11862444X', 'Kurt Tucholsky', 296.0],
#        ['118607960', 'August Wilhelm von Schlegel', 294.0],
#        ['118520040', 'Adelbert von Chamisso', 291.0],
#        ['118633600', 'Johann Joachim Winckelmann', 291.0],
#        ['102840466', 'Niemand', 288.0],
#        ['118543032', 'Andreas Gryphius', 288.0],
#        ['118511742', 'Ernst Bloch', 285.0],
#        ['118629867', 'Frank Wedekind', 284.0],
#        ['118563386', 'Friedrich Gottlieb Klopstock', 283.0],
#        ['11548048X', 'Marcel Beyer', 283.0],
#        ['118541013', 'Johann Christoph Gottsched', 283.0],
#        ['118512161', 'Johannes Bobrowski', 282.0],
#        ['118634682', 'Gerhard Wolf', 280.0],
#        ['118604627', 'Nelly Sachs', 280.0],
#        ['1231289600', 'Klaus Peter', 276.0],
#        ['118502921', 'Lou Andreas-Salomé', 275.0],
#        ['118506234', 'Hugo Ball', 272.0],
#        ['118546910', 'Carl Hauptmann', 272.0],
#        ['124059996', 'Stefan Neuhaus', 269.0],
#        ['118531905', 'Hans Fallada', 268.0],
#        ['1243920327', 'Johann André', 267.0],
#        ['118590111', 'Martin Opitz', 267.0],
#        ['103127178', 'Rost', 263.0],
#        ['118565133', 'von Würzburg Konrad', 262.0],
#        ['118664123', 'Hans Blumenberg', 261.0],
#        ['11955688X', 'Marlene Streeruwitz', 261.0],
#        ['118607057', 'Friedrich Wilhelm Joseph von Schelling', 261.0],
#        ['118569767', 'Sophie von La Roche', 258.0],
#        ['101223749', 'Heinz Pol', 256.0],
#        ['122869192', 'Paul Michael Lützeler', 255.0],
#        ['118536672', 'Franz Fühmann', 253.0],
#        ['11860922X', 'Carl Schmitt', 251.0],
#        ['116807318', 'Theodor Friedrich', 248.0],
#        ['119071738', 'Ruth Klüger', 248.0],
#        ['117744727', 'Heinz Rölleke', 245.0],
#        ['120159872', 'Thomas Martin', 245.0],
#        ['118547453', 'Johann Peter Hebel', 245.0],
#        ['115834087', 'Ulrike Draesner', 243.0],
#        ['118842269', 'Monika Maron', 240.0]], dtype=object)

# %%
wrong_result_authors={
    '116804521' : 0, # Friedrich Friedrich
    '137325355' : 0, # Heinrich
    '1016491166' : 0, # L. A. Paul
    '118558749' : 0, # C. G. Jung
    '1178632180' : 0, # O.F. Berg
    '1112471774' : 0, # Albrecht
    '118581783' : 0, # E. Y. Meyer
    '120404389' : 0, # P. D. James
    '119403412' : 0, #  E. A. Richter
    '128822724' : 0, # D. B. C. Pierre
    '118534408' : 0, # E. M. Forster
    '119545780' : 0, # F. Zell
    '118934163' : 0, # Bai Li
    '118500708' : 0, # H. G. Adler
    '118841386' : 0, # Wu Sun
    '116067624' : 0, # H. W. Katz
    '102840466' : 0, # Niemand
    '103127178' : 0, # Rost
    '12332243X' : 0, # Grosser, J. F. G.
    '11924246X' : 0, # Said (wrong one)
    '118534424' : 0, # Georg Forster (wrong one)
    '122541332' : 0, # Richard Wagner (wrong one)
}

for gnd_id, true_hits in wrong_result_authors.items():
    index_to_fix = bdsl.query("GND == @gnd_id").index
    bdsl.loc[index_to_fix, 'BDSL_hits_2000_all'] = true_hits

# %%
bdsl.sort_values(by='BDSL_hits_2000_all', ascending=False).head(10)
# Out:
#             GND           BDSL_searchphrase  BDSL_hits_2000_all
# 3326  118540238  Johann Wolfgang von Goethe             10227.0
# 3636  118559230                 Franz Kafka              4864.0
# 3888  118577166                 Thomas Mann              4798.0
# 4296  118607626          Friedrich Schiller              3890.0
# 3696  118563076         Heinrich von Kleist              3334.0
# 4050  118587943         Friedrich Nietzsche              3296.0
# 2954  118514768              Bertolt Brecht              3179.0
# 3544  118552465           E. T. A. Hoffmann              3016.0
# 2880  118509039             Walter Benjamin              2951.0
# 3463  118548018              Heinrich Heine              2460.0

# %% [markdown]
# ## staatsexamen

# %%
staatsexamen = pd.read_csv("../raw_data/staatsexamen.csv", encoding='latin1', sep=";")
staatsexamen = staatsexamen.query("GND.notna()")
staatsexamen['GND'] = staatsexamen['GND'].apply(lambda x : x.split('/')[-1])
staatsexamen = staatsexamen[['GND', 'count_exams']]
staatsexamen = staatsexamen.rename(columns={'count_exams' : 'staatsexamen_count'})
staatsexamen['staatsexamen_count'] = staatsexamen['staatsexamen_count'].apply(lambda x : x.replace(",", ".")).astype(float)
staatsexamen = staatsexamen.groupby('GND')['staatsexamen_count'].sum().to_frame().reset_index() # deal with 118547453 Hebel

# %%
staatsexamen
# Out:
#            GND  staatsexamen_count
# 0    118505602                 2.0
# 1    118507931                 1.0
# 2    118509047                 8.0
# 3    118509861                 1.0
# 4    118510665                 1.0
# ..         ...                 ...
# 102  119390388                 1.0
# 103  119527405                 1.0
# 104  119539055                 1.0
# 105  120455293                 1.0
# 106  12989432X                 1.0
#
# [107 rows x 2 columns]

# %% [markdown]
# ## schullist

# %%
schullist_files = [x for x in files if 'schullist' in x]

# %%
# prepare individual schullists
schullists = {}

for this_file in schullist_files:
    schullist_name = this_file.split("/")[-1].split(".")[0]
    schullist_df = pd.read_csv(this_file)
    schullist_df = schullist_df.query("GND.notna()")
    schullist_df['GND'] = schullist_df['GND'].astype(str)
    schullist_df['GND'] = schullist_df['GND'].apply(lambda x : x.split('/')[-1])
    schullist_df = expand_multiple_ids(schullist_df)
    schullist_df = schullist_df['GND'].value_counts().to_frame().reset_index()
    schullist_df = schullist_df.rename(columns={'count' : f'{schullist_name}_count'})
    schullist_df[f'{schullist_name}_share'] = schullist_df[f'{schullist_name}_count']/schullist_df[f'{schullist_name}_count'].sum()
    
    schullists[schullist_name] = schullist_df

# %%
# merge schullists
schullist_iter = iter(schullists.items())
first_name, schullist_merged = next(schullist_iter)

for schullist_name, schullist_df in schullist_iter:
    schullist_merged = pd.merge(
        schullist_merged,
        schullist_df,
        on='GND',
        how='outer',
    )
schullist_merged = schullist_merged.fillna(0).reset_index(drop=True)

# %%
schullist_merged.sort_values(by='schullist_bayern_share', ascending=False)
# Out:
#             GND  schullist_nordrheinwestfalen_count  \
# 119   118527908                                 0.0
# 291   118607626                                 0.0
# 234   118571680                                 0.0
# 148   118540238                                 1.0
# 312   118618725                                 0.0
# ..          ...                                 ...
# 3    1026215927                                 0.0
# 4    1026450284                                 0.0
# 5    103127362X                                 0.0
# 6    1038169879                                 0.0
# 7    1041246439                                 0.0
#
#      schullist_nordrheinwestfalen_share  schullist_bayern_count  \
# 119                                 0.0                     6.0
# 291                                 0.0                     5.0
# 234                                 0.0                     4.0
# 148                                 0.2                     4.0
# 312                                 0.0                     4.0
# ..                                  ...                     ...
# 3                                   0.0                     0.0
# 4                                   0.0                     0.0
# 5                                   0.0                     0.0
# 6                                   0.0                     0.0
# 7                                   0.0                     0.0
#
#      schullist_bayern_share  schullist_sachsenanhalt_count  \
# 119                0.023810                            5.0
# 291                0.019841                            7.0
# 234                0.015873                            8.0
# 148                0.015873                            5.0
# 312                0.015873                            2.0
# ..                      ...                            ...
# 3                  0.000000                            0.0
# 4                  0.000000                            0.0
# 5                  0.000000                            0.0
# 6                  0.000000                            0.0
# 7                  0.000000                            0.0
#
#      schullist_sachsenanhalt_share  schullist_hamburg_count  \
# 119                       0.013263                      0.0
# 291                       0.018568                      0.0
# 234                       0.021220                      0.0
# 148                       0.013263                      0.0
# 312                       0.005305                      0.0
# ..                             ...                      ...
# 3                         0.000000                      0.0
# 4                         0.000000                      0.0
# 5                         0.000000                      0.0
# 6                         0.000000                      0.0
# 7                         0.000000                      0.0
#
#      schullist_hamburg_share  schullist_sachsen_count  ...  \
# 119                      0.0                      3.0  ...
# 291                      0.0                      2.0  ...
# 234                      0.0                      1.0  ...
# 148                      0.0                      2.0  ...
# 312                      0.0                      0.0  ...
# ..                       ...                      ...  ...
# 3                        0.0                      0.0  ...
# 4                        0.0                      0.0  ...
# 5                        0.0                      0.0  ...
# 6                        0.0                      0.0  ...
# 7                        0.0                      0.0  ...
#
#      schullist_saarland_count  schullist_saarland_share  \
# 119                       4.0                  0.051948
# 291                       4.0                  0.051948
# 234                       0.0                  0.000000
# 148                       3.0                  0.038961
# 312                       1.0                  0.012987
# ..                        ...                       ...
# 3                         0.0                  0.000000
# 4                         1.0                  0.012987
# 5                         0.0                  0.000000
# 6                         0.0                  0.000000
# 7                         0.0                  0.000000
#
#      schullist_hessen_count  schullist_hessen_share  schullist_bremen_count  \
# 119                     4.0                0.013746                     0.0
# 291                     6.0                0.020619                     1.0
# 234                     3.0                0.010309                     0.0
# 148                     9.0                0.030928                     3.0
# 312                     1.0                0.003436                     0.0
# ..                      ...                     ...                     ...
# 3                       0.0                0.000000                     0.0
# 4                       0.0                0.000000                     0.0
# 5                       0.0                0.000000                     0.0
# 6                       0.0                0.000000                     0.0
# 7                       0.0                0.000000                     0.0
#
#      schullist_bremen_share  schullist_brandenburg_count  \
# 119                0.000000                          0.0
# 291                0.033333                          3.0
# 234                0.000000                          0.0
# 148                0.100000                          1.0
# 312                0.000000                          0.0
# ..                      ...                          ...
# 3                  0.000000                          0.0
# 4                  0.000000                          0.0
# 5                  0.000000                          0.0
# 6                  0.000000                          0.0
# 7                  0.000000                          0.0
#
#      schullist_brandenburg_share  schullist_badenwuerttemberg_count  \
# 119                     0.000000                                3.0
# 291                     0.115385                                8.0
# 234                     0.000000                                2.0
# 148                     0.038462                                8.0
# 312                     0.000000                                2.0
# ..                           ...                                ...
# 3                       0.000000                                0.0
# 4                       0.000000                                0.0
# 5                       0.000000                                0.0
# 6                       0.000000                                0.0
# 7                       0.000000                                0.0
#
#      schullist_badenwuerttemberg_share
# 119                            0.00813
# 291                            0.02168
# 234                            0.00542
# 148                            0.02168
# 312                            0.00542
# ..                                 ...
# 3                              0.00000
# 4                              0.00000
# 5                              0.00000
# 6                              0.00000
# 7                              0.00000
#
# [674 rows x 27 columns]

# %% [markdown]
# ## abi

# %%
abi = pd.read_csv("../raw_data/abi.csv")
abi = abi[['GND', 'mentions']]
abi = abi.rename(columns={'mentions' : 'abi_mentions'})

# %%
abi
# Out:
#           GND  abi_mentions
# 0   120013428             1
# 1   119520621             1
# 2   118599631             1
# 3   118559427             1
# 4   118520040             1
# ..        ...           ...
# 72  118534262            33
# 73  118563076            37
# 74  118607626            41
# 75  118559230            47
# 76  118540238            48
#
# [77 rows x 2 columns]

# %% [markdown]
# ## wiki

# %%
wiki = pd.read_csv("../raw_data/wiki.csv", index_col=[0])
wiki.columns = ['wiki_'+x if x != 'GND' else x for x in wiki.columns]

fill_columns = ['wiki_length_in_words', 'wiki_number_of_sitelinks', 'wiki_number_of_pageviews_last_5_years', 'wiki_number_of_in_links']
wiki[fill_columns] = wiki[fill_columns].fillna(0)

# %%
wiki
# Out:
#        wiki_page_found                                      wiki_page_url  \
# 0                 True    https://de.wikipedia.org/wiki/Johann_Altenstaig
# 1                 True     https://de.wikipedia.org/wiki/Andreas_Althamer
# 2                 True  https://de.wikipedia.org/wiki/Anna_Sophia_von_...
# 3                 True  https://de.wikipedia.org/wiki/Paul_Bachmann_%2...
# 4                 True  https://de.wikipedia.org/wiki/Ignaz_Ferdinand_...
# ...                ...                                                ...
# 10381             True     https://de.wikipedia.org/wiki/Michael_D._Green
# 10382            False                                                NaN
# 10383            False                                                NaN
# 10384             True         https://de.wikipedia.org/wiki/Irma_Emmrich
# 10385             True  https://de.wikipedia.org/wiki/Otto_A._B%C3%B6hmer
#
#                         wiki_page_title wiki_item_id  wiki_length_in_words  \
# 0                     Johann Altenstaig    Q21544072                 692.0
# 1                      Andreas Althamer       Q96832                 796.0
# 2      Anna Sophia von Hessen-Darmstadt      Q290123                 782.0
# 3                   Paul Bachmann (Abt)     Q2058772                 441.0
# 4                Ignaz Ferdinand Arnold      Q999874                 672.0
# ...                                 ...          ...                   ...
# 10381                  Michael D. Green   Q112512246                 256.0
# 10382                               NaN          NaN                   0.0
# 10383                               NaN          NaN                   0.0
# 10384                      Irma Emmrich    Q56282814                 508.0
# 10385                    Otto A. Böhmer     Q2038056                 498.0
#
#        wiki_number_of_sitelinks  wiki_number_of_pageviews_last_5_years  \
# 0                           1.0                                  641.0
# 1                           7.0                                 2129.0
# 2                          14.0                                 2682.0
# 3                           1.0                                  643.0
# 4                           3.0                                 1482.0
# ...                         ...                                    ...
# 10381                       1.0                                  308.0
# 10382                       0.0                                    0.0
# 10383                       0.0                                    0.0
# 10384                       1.0                                 1164.0
# 10385                       1.0                                 4697.0
#
#        wiki_number_of_in_links        GND
# 0                         15.0  100010350
# 1                         38.0  100010423
# 2                         59.0  100011780
# 3                         22.0  100013945
# 4                         24.0  100017045
# ...                        ...        ...
# 10381                     13.0  174039921
# 10382                      0.0  174061595
# 10383                      0.0  17406165X
# 10384                     18.0  174166087
# 10385                     29.0  189410000
#
# [10386 rows x 9 columns]

# %% [markdown]
# ## kanonspiel

# %%
kanonspiel = pd.read_csv("../raw_data/kanonspiel.csv")
kanonspiel = kanonspiel.groupby('GND')['points'].sum().to_frame().reset_index()
kanonspiel = kanonspiel.rename(columns={'points' : 'kanonspiel_points'})

# %%
kanonspiel.sort_values(by='kanonspiel_points', ascending=False)
# Out:
#           GND  kanonspiel_points
# 26  118540238               4961
# 55  118577166               3444
# 47  118563076               3305
# 10  118514768               3225
# 65  118607626               3202
# ..        ...                ...
# 38  118552759                259
# 22  118530534                253
# 6   118510789                248
# 81  118706187                244
# 63  118603957                223
#
# [88 rows x 2 columns]

# %% [markdown]
# ## segebrecht

# %%
segebrecht = pd.read_csv("../raw_data/segebrecht.csv", sep=";")
segebrecht = expand_multiple_ids(segebrecht)
segebrecht = segebrecht.query("GND.notna()")
segebrecht = segebrecht.query("type.isna()") # exclude anthologies
segebrecht = segebrecht['GND'].value_counts().to_frame().reset_index()
segebrecht = segebrecht.rename(columns={'count' : 'segebrecht_count'})

# %%
segebrecht
# Out:
#            GND  segebrecht_count
# 0    118540238                23
# 1    118607626                15
# 2    118534262                10
# 3    118514768                 9
# 4    118577166                 9
# ..         ...               ...
# 346  118636596                 1
# 347  118599518                 1
# 348  118625306                 1
# 349  118696696                 1
# 350  118586874                 1
#
# [351 rows x 2 columns]

# %% [markdown]
# ## vv_hein

# %%
vv_hein = pd.read_csv("../raw_data/vv_hein.csv", sep=";")
vv_hein = vv_hein.rename(columns={'GND-Nummer' : 'GND', 'Gesamt_count' : 'vv_hein_count'})
vv_hein = vv_hein.query("GND.notna()")
vv_hein['vv_hein_count'] = vv_hein['vv_hein_count'].apply(lambda x : x.split(' ')[0])
vv_hein = vv_hein[['GND', 'vv_hein_count']]

# %%
vv_hein
# Out:
#            GND vv_hein_count
# 0    118542273            17
# 1    118543032            17
# 2    118590111             4
# 4    118630369             2
# 5    116551968             1
# ..         ...           ...
# 173  11850391X             1
# 174  118829211             1
# 175  118507397             1
# 176  118508091             1
# 177  118829742             1
#
# [152 rows x 2 columns]

# %% [markdown]
# ## gnd

# %%
def convert_to_year(date):
    if pd.isna(date):
        return date
    else:
        date_parts = date.split('-')
        if date_parts[0] == '':
            bc = True
            date = date_parts[1]
        else:
            bc = False
            date = date_parts[0]
        date = date.replace('X', '0')
        match = re.findall(r"\d+", date)
        if match:
            date = int(match[0])
            if bc:
                date = -date
            return date
        else:
            print(date)
            return None

# %%
gnd = pd.read_csv("../raw_data/gnd.csv", index_col=[0])
gnd['GND_birth'] = gnd['GND_birth'].apply(convert_to_year)
gnd['GND_death'] = gnd['GND_death'].apply(convert_to_year)

# %%
gnd
# Out:
#              GND                                   GND_name GND_gender  \
# 0      100010350                         Altenstaig, Johann   Männlich
# 1      100010423                          Althamer, Andreas   Männlich
# 2      100011780  Anna Sophie, Hessen-Darmstadt, Landgräfin   Weiblich
# 3      100013945                             Bachmann, Paul  Unbekannt
# 4      100017045                    Arnold, Ignaz Ferdinand   Männlich
# ...          ...                                        ...        ...
# 10381  174039921                          Green, Michael D.  Unbekannt
# 10382  174061595                           Kröger, Wolfgang  Unbekannt
# 10383  17406165X                           Großmann, Dieter   Männlich
# 10384  174166087                              Emmrich, Irma   Weiblich
# 10385  189410000                            Böhmer, Otto A.   Männlich
#
#        GND_birth  GND_death  \
# 0         1480.0     1523.0
# 1         1500.0     1539.0
# 2         1638.0     1683.0
# 3            NaN     1538.0
# 4         1774.0     1812.0
# ...          ...        ...
# 10381     1941.0        NaN
# 10382     1947.0     2005.0
# 10383     1921.0     1997.0
# 10384     1919.0     2018.0
# 10385     1949.0        NaN
#
#                                           GND_occupation  \
# 0              Humanist + Humanist + Theologe + Priester
# 1      Evangelischer Theologe + Reformator + Humanist...
# 2                                               Äbtissin
# 3                                            Mönch + Abt
# 4      Schriftsteller + Jurist + Musikwissenschaftler...
# ...                                                  ...
# 10381                                         Historiker
# 10382                                                NaN
# 10383                       Kunsthistoriker + Archäologe
# 10384                                  Kunsthistorikerin
# 10385                   Schriftsteller + Lektor <Verlag>
#
#                            GND_country
# 0                          Deutschland
# 1                          Deutschland
# 2                          Deutschland
# 3                          Deutschland
# 4                          Deutschland
# ...                                ...
# 10381                              USA
# 10382                              NaN
# 10383              Polen + Deutschland
# 10384  Deutschland + Deutschland (DDR)
# 10385                      Deutschland
#
# [10386 rows x 7 columns]

# %% [markdown]
# # merge

# %%
data = pd.merge(
    unilist_merged,
    litges_merged,
    on='GND',
    how='outer'
).merge(
    vv_merged,
    on='GND',
    how='outer'
).merge(
    killy,
    on='GND',
    how='outer'
).merge(
    reclam,
    on='GND',
    how='outer'
).merge(
    staatsexamen,
    on='GND',
    how='outer'
).merge(
    schullist_merged,
    on='GND',
    how='outer'
).merge(
    abi,
    on='GND',
    how='outer'
).merge(
    kanonspiel,
    on='GND',
    how='outer'
).merge(
    segebrecht,
    on='GND',
    how='outer'
).merge(
    vv_hein,
    on='GND',
    how='outer'
).fillna(0).reset_index(drop=True)

# %%
data = data.merge(
    gnd,
    on='GND',
    how='left'
)

data = data.merge(
    wiki,
    on='GND',
    how='left'
)

data = data.merge(
    bdsl,
    on='GND',
    how='left'
)

# %%
data.sort_values(by='page_count_litges_brenner', ascending=False)
# Out:
#             GND  prob_to_read_sum_unilist_heidelberg_2017  \
# 3457  118540238                                  5.727273
# 4040  118577166                                  1.194805
# 3072  118514768                                  1.728571
# 4468  118607626                                  3.636364
# 3481  118541579                                  0.142857
# ...         ...                                       ...
# 9591  173023126                                  0.000000
# 9592  173054072                                  0.000000
# 9593  173090257                                  0.000000
# 9594  173150594                                  0.000000
# 7     100019382                                  0.000000
#
#       prob_to_read_share_unilist_heidelberg_2017  \
# 3457                                    0.086515
# 4040                                    0.018048
# 3072                                    0.026111
# 4468                                    0.054930
# 3481                                    0.002158
# ...                                          ...
# 9591                                    0.000000
# 9592                                    0.000000
# 9593                                    0.000000
# 9594                                    0.000000
# 7                                       0.000000
#
#       prob_to_read_sum_unilist_aachen_201718  \
# 3457                                2.492755
# 4040                                0.176000
# 3072                                0.691000
# 4468                                2.216484
# 3481                                1.000000
# ...                                      ...
# 9591                                0.000000
# 9592                                0.000000
# 9593                                0.000000
# 9594                                0.000000
# 7                                   0.000000
#
#       prob_to_read_share_unilist_aachen_201718  \
# 3457                                  0.040582
# 4040                                  0.002865
# 3072                                  0.011249
# 4468                                  0.036084
# 3481                                  0.016280
# ...                                        ...
# 9591                                  0.000000
# 9592                                  0.000000
# 9593                                  0.000000
# 9594                                  0.000000
# 7                                     0.000000
#
#       prob_to_read_sum_unilist_goettingen  \
# 3457                             6.000000
# 4040                             3.000000
# 3072                             1.000000
# 4468                             3.333333
# 3481                             1.000000
# ...                                   ...
# 9591                             0.000000
# 9592                             0.000000
# 9593                             0.000000
# 9594                             0.000000
# 7                                0.000000
#
#       prob_to_read_share_unilist_goettingen  \
# 3457                               0.093750
# 4040                               0.046875
# 3072                               0.015625
# 4468                               0.052083
# 3481                               0.015625
# ...                                     ...
# 9591                               0.000000
# 9592                               0.000000
# 9593                               0.000000
# 9594                               0.000000
# 7                                  0.000000
#
#       prob_to_read_sum_unilist_luxemburg  \
# 3457                                 7.0
# 4040                                 1.0
# 3072                                 1.0
# 4468                                 3.0
# 3481                                 1.0
# ...                                  ...
# 9591                                 0.0
# 9592                                 0.0
# 9593                                 0.0
# 9594                                 0.0
# 7                                    0.0
#
#       prob_to_read_share_unilist_luxemburg  \
# 3457                              0.097222
# 4040                              0.013889
# 3072                              0.013889
# 4468                              0.041667
# 3481                              0.013889
# ...                                    ...
# 9591                              0.000000
# 9592                              0.000000
# 9593                              0.000000
# 9594                              0.000000
# 7                                 0.000000
#
#       prob_to_read_sum_unilist_graz_2021  ...  wiki_page_found  \
# 3457                                 4.0  ...             True
# 4040                                 1.0  ...             True
# 3072                                 3.0  ...             True
# 4468                                 2.0  ...             True
# 3481                                 1.0  ...             True
# ...                                  ...  ...              ...
# 9591                                 0.0  ...            False
# 9592                                 0.0  ...            False
# 9593                                 0.0  ...            False
# 9594                                 0.0  ...            False
# 7                                    0.0  ...             True
#
#                                           wiki_page_url  \
# 3457  https://de.wikipedia.org/wiki/Johann_Wolfgang_...
# 4040          https://de.wikipedia.org/wiki/Thomas_Mann
# 3072       https://de.wikipedia.org/wiki/Bertolt_Brecht
# 4468   https://de.wikipedia.org/wiki/Friedrich_Schiller
# 3481    https://de.wikipedia.org/wiki/G%C3%BCnter_Grass
# ...                                                 ...
# 9591                                                NaN
# 9592                                                NaN
# 9593                                                NaN
# 9594                                                NaN
# 7     https://de.wikipedia.org/wiki/Nicolaus_von_Ava...
#
#                  wiki_page_title  wiki_item_id  wiki_length_in_words  \
# 3457  Johann Wolfgang von Goethe         Q5879               36790.0
# 4040                 Thomas Mann        Q37030               15597.0
# 3072              Bertolt Brecht        Q38757               18391.0
# 4468          Friedrich Schiller        Q22670               13856.0
# 3481                Günter Grass         Q6538               11937.0
# ...                          ...           ...                   ...
# 9591                         NaN           NaN                   0.0
# 9592                         NaN           NaN                   0.0
# 9593                         NaN           NaN                   0.0
# 9594                         NaN           NaN                   0.0
# 7          Nicolaus von Avancini      Q3340050                 459.0
#
#       wiki_number_of_sitelinks  wiki_number_of_pageviews_last_5_years  \
# 3457                     272.0                              3648043.0
# 4040                     160.0                              2329343.0
# 3072                     152.0                              2315455.0
# 4468                     180.0                              2042583.0
# 3481                     137.0                               984546.0
# ...                        ...                                    ...
# 9591                       0.0                                    0.0
# 9592                       0.0                                    0.0
# 9593                       0.0                                    0.0
# 9594                       0.0                                    0.0
# 7                         12.0                                 1689.0
#
#       wiki_number_of_in_links           BDSL_searchphrase  BDSL_hits_2000_all
# 3457                  11289.0  Johann Wolfgang von Goethe             10227.0
# 4040                   3879.0                 Thomas Mann              4798.0
# 3072                   5041.0              Bertolt Brecht              3179.0
# 4468                   6329.0          Friedrich Schiller              3890.0
# 3481                   1685.0                Günter Grass              1685.0
# ...                       ...                         ...                 ...
# 9591                      0.0          Günther Distelrath                 0.0
# 9592                      0.0         Marc Olivier Baruch                 0.0
# 9593                      0.0                  Bill Brown                 0.0
# 9594                      0.0                   Uta Plate                 0.0
# 7                        32.0            Niccolò Avancini                 5.0
#
# [9628 rows x 144 columns]

# %%
data['GND'].value_counts()
# Out:
# GND
# 189568798    1
# 100010350    1
# 100010423    1
# 100011780    1
# 100013945    1
#             ..
# 100092381    1
# 100099459    1
# 100101844    1
# 100110274    1
# 10011153X    1
# Name: count, Length: 9628, dtype: int64

# %%
data.query("GND.str.contains(r'\\+')")
# Out:
# Empty DataFrame
# Columns: [GND, prob_to_read_sum_unilist_heidelberg_2017, prob_to_read_share_unilist_heidelberg_2017, prob_to_read_sum_unilist_aachen_201718, prob_to_read_share_unilist_aachen_201718, prob_to_read_sum_unilist_goettingen, prob_to_read_share_unilist_goettingen, prob_to_read_sum_unilist_luxemburg, prob_to_read_share_unilist_luxemburg, prob_to_read_sum_unilist_graz_2021, prob_to_read_share_unilist_graz_2021, prob_to_read_sum_unilist_saarland_2007, prob_to_read_share_unilist_saarland_2007, prob_to_read_sum_unilist_magdeburg_2020, prob_to_read_share_unilist_magdeburg_2020, prob_to_read_sum_unilist_tuebingen, prob_to_read_share_unilist_tuebingen, prob_to_read_sum_unilist_leipzig, prob_to_read_share_unilist_leipzig, prob_to_read_sum_unilist_salzburg, prob_to_read_share_unilist_salzburg, prob_to_read_sum_unilist_passau, prob_to_read_share_unilist_passau, prob_to_read_sum_unilist_wuerzburg_2019, prob_to_read_share_unilist_wuerzburg_2019, prob_to_read_sum_unilist_bochum, prob_to_read_share_unilist_bochum, prob_to_read_sum_unilist_muenchen, prob_to_read_share_unilist_muenchen, prob_to_read_sum_unilist_jena_2018, prob_to_read_share_unilist_jena_2018, prob_to_read_sum_unilist_mannheim, prob_to_read_share_unilist_mannheim, prob_to_read_sum_unilist_wuppertal_2015, prob_to_read_share_unilist_wuppertal_2015, prob_to_read_sum_unilist_gießen, prob_to_read_share_unilist_gießen, prob_to_read_sum_unilist_innsbruck_2023, prob_to_read_share_unilist_innsbruck_2023, prob_to_read_sum_unilist_augsburg_2020, prob_to_read_share_unilist_augsburg_2020, prob_to_read_sum_unilist_koeln, prob_to_read_share_unilist_koeln, prob_to_read_sum_unilist_oldenburg_2020, prob_to_read_share_unilist_oldenburg_2020, prob_to_read_sum_unilist_eichstaettingolstadt_2007, prob_to_read_share_unilist_eichstaettingolstadt_2007, prob_to_read_sum_unilist_karlsruhe, prob_to_read_share_unilist_karlsruhe, prob_to_read_sum_unilist_trier, prob_to_read_share_unilist_trier, prob_to_read_sum_unilist_potsdam_2022, prob_to_read_share_unilist_potsdam_2022, prob_to_read_sum_unilist_frankfurt_am, prob_to_read_share_unilist_frankfurt_am, prob_to_read_sum_unilist_hildesheim, prob_to_read_share_unilist_hildesheim, prob_to_read_sum_unilist_lueneburg, prob_to_read_share_unilist_lueneburg, prob_to_read_sum_unilist_braunschweig, prob_to_read_share_unilist_braunschweig, prob_to_read_sum_unilist_wien, prob_to_read_share_unilist_wien, prob_to_read_sum_unilist_lausanne, prob_to_read_share_unilist_lausanne, prob_to_read_sum_unilist_koblenz, prob_to_read_share_unilist_koblenz, prob_to_read_sum_unilist_stuttgart, prob_to_read_share_unilist_stuttgart, prob_to_read_sum_unilist_wuerzburg_200304, prob_to_read_share_unilist_wuerzburg_200304, prob_to_read_sum_unilist_dortmund, prob_to_read_share_unilist_dortmund, prob_to_read_sum_unilist_stuttgart_2022, prob_to_read_share_unilist_stuttgart_2022, prob_to_read_sum_unilist_innsbruck, prob_to_read_share_unilist_innsbruck, prob_to_read_sum_unilist_osnabrueck, prob_to_read_share_unilist_osnabrueck, prob_to_read_sum_unilist_la_aachen_2018, prob_to_read_share_unilist_la_aachen_2018, prob_to_read_sum_unilist_fu_berlin, prob_to_read_share_unilist_fu_berlin, prob_to_read_sum_unilist_zuerich_2013, prob_to_read_share_unilist_zuerich_2013, page_count_litges_beutin, page_count_rel_litges_beutin, page_count_litges_brenner, page_count_rel_litges_brenner, event_count_vv_mainz, event_count_rel_vv_mainz, event_count_vv_stuttgart, event_count_rel_vv_stuttgart, event_count_vv_wien, event_count_rel_vv_wien, killy_length, reclam_count, staatsexamen_count, schullist_nordrheinwestfalen_count, schullist_nordrheinwestfalen_share, ...]
# Index: []
#
# [0 rows x 144 columns]

# %%
data.query("GND.str.contains(r'n')")
# Out:
# Empty DataFrame
# Columns: [GND, prob_to_read_sum_unilist_heidelberg_2017, prob_to_read_share_unilist_heidelberg_2017, prob_to_read_sum_unilist_aachen_201718, prob_to_read_share_unilist_aachen_201718, prob_to_read_sum_unilist_goettingen, prob_to_read_share_unilist_goettingen, prob_to_read_sum_unilist_luxemburg, prob_to_read_share_unilist_luxemburg, prob_to_read_sum_unilist_graz_2021, prob_to_read_share_unilist_graz_2021, prob_to_read_sum_unilist_saarland_2007, prob_to_read_share_unilist_saarland_2007, prob_to_read_sum_unilist_magdeburg_2020, prob_to_read_share_unilist_magdeburg_2020, prob_to_read_sum_unilist_tuebingen, prob_to_read_share_unilist_tuebingen, prob_to_read_sum_unilist_leipzig, prob_to_read_share_unilist_leipzig, prob_to_read_sum_unilist_salzburg, prob_to_read_share_unilist_salzburg, prob_to_read_sum_unilist_passau, prob_to_read_share_unilist_passau, prob_to_read_sum_unilist_wuerzburg_2019, prob_to_read_share_unilist_wuerzburg_2019, prob_to_read_sum_unilist_bochum, prob_to_read_share_unilist_bochum, prob_to_read_sum_unilist_muenchen, prob_to_read_share_unilist_muenchen, prob_to_read_sum_unilist_jena_2018, prob_to_read_share_unilist_jena_2018, prob_to_read_sum_unilist_mannheim, prob_to_read_share_unilist_mannheim, prob_to_read_sum_unilist_wuppertal_2015, prob_to_read_share_unilist_wuppertal_2015, prob_to_read_sum_unilist_gießen, prob_to_read_share_unilist_gießen, prob_to_read_sum_unilist_innsbruck_2023, prob_to_read_share_unilist_innsbruck_2023, prob_to_read_sum_unilist_augsburg_2020, prob_to_read_share_unilist_augsburg_2020, prob_to_read_sum_unilist_koeln, prob_to_read_share_unilist_koeln, prob_to_read_sum_unilist_oldenburg_2020, prob_to_read_share_unilist_oldenburg_2020, prob_to_read_sum_unilist_eichstaettingolstadt_2007, prob_to_read_share_unilist_eichstaettingolstadt_2007, prob_to_read_sum_unilist_karlsruhe, prob_to_read_share_unilist_karlsruhe, prob_to_read_sum_unilist_trier, prob_to_read_share_unilist_trier, prob_to_read_sum_unilist_potsdam_2022, prob_to_read_share_unilist_potsdam_2022, prob_to_read_sum_unilist_frankfurt_am, prob_to_read_share_unilist_frankfurt_am, prob_to_read_sum_unilist_hildesheim, prob_to_read_share_unilist_hildesheim, prob_to_read_sum_unilist_lueneburg, prob_to_read_share_unilist_lueneburg, prob_to_read_sum_unilist_braunschweig, prob_to_read_share_unilist_braunschweig, prob_to_read_sum_unilist_wien, prob_to_read_share_unilist_wien, prob_to_read_sum_unilist_lausanne, prob_to_read_share_unilist_lausanne, prob_to_read_sum_unilist_koblenz, prob_to_read_share_unilist_koblenz, prob_to_read_sum_unilist_stuttgart, prob_to_read_share_unilist_stuttgart, prob_to_read_sum_unilist_wuerzburg_200304, prob_to_read_share_unilist_wuerzburg_200304, prob_to_read_sum_unilist_dortmund, prob_to_read_share_unilist_dortmund, prob_to_read_sum_unilist_stuttgart_2022, prob_to_read_share_unilist_stuttgart_2022, prob_to_read_sum_unilist_innsbruck, prob_to_read_share_unilist_innsbruck, prob_to_read_sum_unilist_osnabrueck, prob_to_read_share_unilist_osnabrueck, prob_to_read_sum_unilist_la_aachen_2018, prob_to_read_share_unilist_la_aachen_2018, prob_to_read_sum_unilist_fu_berlin, prob_to_read_share_unilist_fu_berlin, prob_to_read_sum_unilist_zuerich_2013, prob_to_read_share_unilist_zuerich_2013, page_count_litges_beutin, page_count_rel_litges_beutin, page_count_litges_brenner, page_count_rel_litges_brenner, event_count_vv_mainz, event_count_rel_vv_mainz, event_count_vv_stuttgart, event_count_rel_vv_stuttgart, event_count_vv_wien, event_count_rel_vv_wien, killy_length, reclam_count, staatsexamen_count, schullist_nordrheinwestfalen_count, schullist_nordrheinwestfalen_share, ...]
# Index: []
#
# [0 rows x 144 columns]

# %%
data.query("GND_name.isna()")
# Out:
# Empty DataFrame
# Columns: [GND, prob_to_read_sum_unilist_heidelberg_2017, prob_to_read_share_unilist_heidelberg_2017, prob_to_read_sum_unilist_aachen_201718, prob_to_read_share_unilist_aachen_201718, prob_to_read_sum_unilist_goettingen, prob_to_read_share_unilist_goettingen, prob_to_read_sum_unilist_luxemburg, prob_to_read_share_unilist_luxemburg, prob_to_read_sum_unilist_graz_2021, prob_to_read_share_unilist_graz_2021, prob_to_read_sum_unilist_saarland_2007, prob_to_read_share_unilist_saarland_2007, prob_to_read_sum_unilist_magdeburg_2020, prob_to_read_share_unilist_magdeburg_2020, prob_to_read_sum_unilist_tuebingen, prob_to_read_share_unilist_tuebingen, prob_to_read_sum_unilist_leipzig, prob_to_read_share_unilist_leipzig, prob_to_read_sum_unilist_salzburg, prob_to_read_share_unilist_salzburg, prob_to_read_sum_unilist_passau, prob_to_read_share_unilist_passau, prob_to_read_sum_unilist_wuerzburg_2019, prob_to_read_share_unilist_wuerzburg_2019, prob_to_read_sum_unilist_bochum, prob_to_read_share_unilist_bochum, prob_to_read_sum_unilist_muenchen, prob_to_read_share_unilist_muenchen, prob_to_read_sum_unilist_jena_2018, prob_to_read_share_unilist_jena_2018, prob_to_read_sum_unilist_mannheim, prob_to_read_share_unilist_mannheim, prob_to_read_sum_unilist_wuppertal_2015, prob_to_read_share_unilist_wuppertal_2015, prob_to_read_sum_unilist_gießen, prob_to_read_share_unilist_gießen, prob_to_read_sum_unilist_innsbruck_2023, prob_to_read_share_unilist_innsbruck_2023, prob_to_read_sum_unilist_augsburg_2020, prob_to_read_share_unilist_augsburg_2020, prob_to_read_sum_unilist_koeln, prob_to_read_share_unilist_koeln, prob_to_read_sum_unilist_oldenburg_2020, prob_to_read_share_unilist_oldenburg_2020, prob_to_read_sum_unilist_eichstaettingolstadt_2007, prob_to_read_share_unilist_eichstaettingolstadt_2007, prob_to_read_sum_unilist_karlsruhe, prob_to_read_share_unilist_karlsruhe, prob_to_read_sum_unilist_trier, prob_to_read_share_unilist_trier, prob_to_read_sum_unilist_potsdam_2022, prob_to_read_share_unilist_potsdam_2022, prob_to_read_sum_unilist_frankfurt_am, prob_to_read_share_unilist_frankfurt_am, prob_to_read_sum_unilist_hildesheim, prob_to_read_share_unilist_hildesheim, prob_to_read_sum_unilist_lueneburg, prob_to_read_share_unilist_lueneburg, prob_to_read_sum_unilist_braunschweig, prob_to_read_share_unilist_braunschweig, prob_to_read_sum_unilist_wien, prob_to_read_share_unilist_wien, prob_to_read_sum_unilist_lausanne, prob_to_read_share_unilist_lausanne, prob_to_read_sum_unilist_koblenz, prob_to_read_share_unilist_koblenz, prob_to_read_sum_unilist_stuttgart, prob_to_read_share_unilist_stuttgart, prob_to_read_sum_unilist_wuerzburg_200304, prob_to_read_share_unilist_wuerzburg_200304, prob_to_read_sum_unilist_dortmund, prob_to_read_share_unilist_dortmund, prob_to_read_sum_unilist_stuttgart_2022, prob_to_read_share_unilist_stuttgart_2022, prob_to_read_sum_unilist_innsbruck, prob_to_read_share_unilist_innsbruck, prob_to_read_sum_unilist_osnabrueck, prob_to_read_share_unilist_osnabrueck, prob_to_read_sum_unilist_la_aachen_2018, prob_to_read_share_unilist_la_aachen_2018, prob_to_read_sum_unilist_fu_berlin, prob_to_read_share_unilist_fu_berlin, prob_to_read_sum_unilist_zuerich_2013, prob_to_read_share_unilist_zuerich_2013, page_count_litges_beutin, page_count_rel_litges_beutin, page_count_litges_brenner, page_count_rel_litges_brenner, event_count_vv_mainz, event_count_rel_vv_mainz, event_count_vv_stuttgart, event_count_rel_vv_stuttgart, event_count_vv_wien, event_count_rel_vv_wien, killy_length, reclam_count, staatsexamen_count, schullist_nordrheinwestfalen_count, schullist_nordrheinwestfalen_share, ...]
# Index: []
#
# [0 rows x 144 columns]

# %%
data.query("wiki_page_found.isna()")
# Out:
# Empty DataFrame
# Columns: [GND, prob_to_read_sum_unilist_heidelberg_2017, prob_to_read_share_unilist_heidelberg_2017, prob_to_read_sum_unilist_aachen_201718, prob_to_read_share_unilist_aachen_201718, prob_to_read_sum_unilist_goettingen, prob_to_read_share_unilist_goettingen, prob_to_read_sum_unilist_luxemburg, prob_to_read_share_unilist_luxemburg, prob_to_read_sum_unilist_graz_2021, prob_to_read_share_unilist_graz_2021, prob_to_read_sum_unilist_saarland_2007, prob_to_read_share_unilist_saarland_2007, prob_to_read_sum_unilist_magdeburg_2020, prob_to_read_share_unilist_magdeburg_2020, prob_to_read_sum_unilist_tuebingen, prob_to_read_share_unilist_tuebingen, prob_to_read_sum_unilist_leipzig, prob_to_read_share_unilist_leipzig, prob_to_read_sum_unilist_salzburg, prob_to_read_share_unilist_salzburg, prob_to_read_sum_unilist_passau, prob_to_read_share_unilist_passau, prob_to_read_sum_unilist_wuerzburg_2019, prob_to_read_share_unilist_wuerzburg_2019, prob_to_read_sum_unilist_bochum, prob_to_read_share_unilist_bochum, prob_to_read_sum_unilist_muenchen, prob_to_read_share_unilist_muenchen, prob_to_read_sum_unilist_jena_2018, prob_to_read_share_unilist_jena_2018, prob_to_read_sum_unilist_mannheim, prob_to_read_share_unilist_mannheim, prob_to_read_sum_unilist_wuppertal_2015, prob_to_read_share_unilist_wuppertal_2015, prob_to_read_sum_unilist_gießen, prob_to_read_share_unilist_gießen, prob_to_read_sum_unilist_innsbruck_2023, prob_to_read_share_unilist_innsbruck_2023, prob_to_read_sum_unilist_augsburg_2020, prob_to_read_share_unilist_augsburg_2020, prob_to_read_sum_unilist_koeln, prob_to_read_share_unilist_koeln, prob_to_read_sum_unilist_oldenburg_2020, prob_to_read_share_unilist_oldenburg_2020, prob_to_read_sum_unilist_eichstaettingolstadt_2007, prob_to_read_share_unilist_eichstaettingolstadt_2007, prob_to_read_sum_unilist_karlsruhe, prob_to_read_share_unilist_karlsruhe, prob_to_read_sum_unilist_trier, prob_to_read_share_unilist_trier, prob_to_read_sum_unilist_potsdam_2022, prob_to_read_share_unilist_potsdam_2022, prob_to_read_sum_unilist_frankfurt_am, prob_to_read_share_unilist_frankfurt_am, prob_to_read_sum_unilist_hildesheim, prob_to_read_share_unilist_hildesheim, prob_to_read_sum_unilist_lueneburg, prob_to_read_share_unilist_lueneburg, prob_to_read_sum_unilist_braunschweig, prob_to_read_share_unilist_braunschweig, prob_to_read_sum_unilist_wien, prob_to_read_share_unilist_wien, prob_to_read_sum_unilist_lausanne, prob_to_read_share_unilist_lausanne, prob_to_read_sum_unilist_koblenz, prob_to_read_share_unilist_koblenz, prob_to_read_sum_unilist_stuttgart, prob_to_read_share_unilist_stuttgart, prob_to_read_sum_unilist_wuerzburg_200304, prob_to_read_share_unilist_wuerzburg_200304, prob_to_read_sum_unilist_dortmund, prob_to_read_share_unilist_dortmund, prob_to_read_sum_unilist_stuttgart_2022, prob_to_read_share_unilist_stuttgart_2022, prob_to_read_sum_unilist_innsbruck, prob_to_read_share_unilist_innsbruck, prob_to_read_sum_unilist_osnabrueck, prob_to_read_share_unilist_osnabrueck, prob_to_read_sum_unilist_la_aachen_2018, prob_to_read_share_unilist_la_aachen_2018, prob_to_read_sum_unilist_fu_berlin, prob_to_read_share_unilist_fu_berlin, prob_to_read_sum_unilist_zuerich_2013, prob_to_read_share_unilist_zuerich_2013, page_count_litges_beutin, page_count_rel_litges_beutin, page_count_litges_brenner, page_count_rel_litges_brenner, event_count_vv_mainz, event_count_rel_vv_mainz, event_count_vv_stuttgart, event_count_rel_vv_stuttgart, event_count_vv_wien, event_count_rel_vv_wien, killy_length, reclam_count, staatsexamen_count, schullist_nordrheinwestfalen_count, schullist_nordrheinwestfalen_share, ...]
# Index: []
#
# [0 rows x 144 columns]

# %%
data.query("BDSL_searchphrase.isna()")
# Out:
# Empty DataFrame
# Columns: [GND, prob_to_read_sum_unilist_heidelberg_2017, prob_to_read_share_unilist_heidelberg_2017, prob_to_read_sum_unilist_aachen_201718, prob_to_read_share_unilist_aachen_201718, prob_to_read_sum_unilist_goettingen, prob_to_read_share_unilist_goettingen, prob_to_read_sum_unilist_luxemburg, prob_to_read_share_unilist_luxemburg, prob_to_read_sum_unilist_graz_2021, prob_to_read_share_unilist_graz_2021, prob_to_read_sum_unilist_saarland_2007, prob_to_read_share_unilist_saarland_2007, prob_to_read_sum_unilist_magdeburg_2020, prob_to_read_share_unilist_magdeburg_2020, prob_to_read_sum_unilist_tuebingen, prob_to_read_share_unilist_tuebingen, prob_to_read_sum_unilist_leipzig, prob_to_read_share_unilist_leipzig, prob_to_read_sum_unilist_salzburg, prob_to_read_share_unilist_salzburg, prob_to_read_sum_unilist_passau, prob_to_read_share_unilist_passau, prob_to_read_sum_unilist_wuerzburg_2019, prob_to_read_share_unilist_wuerzburg_2019, prob_to_read_sum_unilist_bochum, prob_to_read_share_unilist_bochum, prob_to_read_sum_unilist_muenchen, prob_to_read_share_unilist_muenchen, prob_to_read_sum_unilist_jena_2018, prob_to_read_share_unilist_jena_2018, prob_to_read_sum_unilist_mannheim, prob_to_read_share_unilist_mannheim, prob_to_read_sum_unilist_wuppertal_2015, prob_to_read_share_unilist_wuppertal_2015, prob_to_read_sum_unilist_gießen, prob_to_read_share_unilist_gießen, prob_to_read_sum_unilist_innsbruck_2023, prob_to_read_share_unilist_innsbruck_2023, prob_to_read_sum_unilist_augsburg_2020, prob_to_read_share_unilist_augsburg_2020, prob_to_read_sum_unilist_koeln, prob_to_read_share_unilist_koeln, prob_to_read_sum_unilist_oldenburg_2020, prob_to_read_share_unilist_oldenburg_2020, prob_to_read_sum_unilist_eichstaettingolstadt_2007, prob_to_read_share_unilist_eichstaettingolstadt_2007, prob_to_read_sum_unilist_karlsruhe, prob_to_read_share_unilist_karlsruhe, prob_to_read_sum_unilist_trier, prob_to_read_share_unilist_trier, prob_to_read_sum_unilist_potsdam_2022, prob_to_read_share_unilist_potsdam_2022, prob_to_read_sum_unilist_frankfurt_am, prob_to_read_share_unilist_frankfurt_am, prob_to_read_sum_unilist_hildesheim, prob_to_read_share_unilist_hildesheim, prob_to_read_sum_unilist_lueneburg, prob_to_read_share_unilist_lueneburg, prob_to_read_sum_unilist_braunschweig, prob_to_read_share_unilist_braunschweig, prob_to_read_sum_unilist_wien, prob_to_read_share_unilist_wien, prob_to_read_sum_unilist_lausanne, prob_to_read_share_unilist_lausanne, prob_to_read_sum_unilist_koblenz, prob_to_read_share_unilist_koblenz, prob_to_read_sum_unilist_stuttgart, prob_to_read_share_unilist_stuttgart, prob_to_read_sum_unilist_wuerzburg_200304, prob_to_read_share_unilist_wuerzburg_200304, prob_to_read_sum_unilist_dortmund, prob_to_read_share_unilist_dortmund, prob_to_read_sum_unilist_stuttgart_2022, prob_to_read_share_unilist_stuttgart_2022, prob_to_read_sum_unilist_innsbruck, prob_to_read_share_unilist_innsbruck, prob_to_read_sum_unilist_osnabrueck, prob_to_read_share_unilist_osnabrueck, prob_to_read_sum_unilist_la_aachen_2018, prob_to_read_share_unilist_la_aachen_2018, prob_to_read_sum_unilist_fu_berlin, prob_to_read_share_unilist_fu_berlin, prob_to_read_sum_unilist_zuerich_2013, prob_to_read_share_unilist_zuerich_2013, page_count_litges_beutin, page_count_rel_litges_beutin, page_count_litges_brenner, page_count_rel_litges_brenner, event_count_vv_mainz, event_count_rel_vv_mainz, event_count_vv_stuttgart, event_count_rel_vv_stuttgart, event_count_vv_wien, event_count_rel_vv_wien, killy_length, reclam_count, staatsexamen_count, schullist_nordrheinwestfalen_count, schullist_nordrheinwestfalen_share, ...]
# Index: []
#
# [0 rows x 144 columns]

# %%
data.query("GND_birth >= 1994")
# Out:
#              GND  prob_to_read_sum_unilist_heidelberg_2017  \
# 946   1072059940                                       0.0
# 1288  1147517223                                       0.0
# 2848  1182074820                                       0.0
# 9102  1307416098                                       0.0
# 9195  1324565837                                       0.0
#
#       prob_to_read_share_unilist_heidelberg_2017  \
# 946                                          0.0
# 1288                                         0.0
# 2848                                         0.0
# 9102                                         0.0
# 9195                                         0.0
#
#       prob_to_read_sum_unilist_aachen_201718  \
# 946                                      0.0
# 1288                                     0.0
# 2848                                     0.0
# 9102                                     0.0
# 9195                                     0.0
#
#       prob_to_read_share_unilist_aachen_201718  \
# 946                                        0.0
# 1288                                       0.0
# 2848                                       0.0
# 9102                                       0.0
# 9195                                       0.0
#
#       prob_to_read_sum_unilist_goettingen  \
# 946                                   0.0
# 1288                                  0.0
# 2848                                  0.0
# 9102                                  0.0
# 9195                                  0.0
#
#       prob_to_read_share_unilist_goettingen  \
# 946                                     0.0
# 1288                                    0.0
# 2848                                    0.0
# 9102                                    0.0
# 9195                                    0.0
#
#       prob_to_read_sum_unilist_luxemburg  \
# 946                                  0.0
# 1288                                 0.0
# 2848                                 0.0
# 9102                                 0.0
# 9195                                 0.0
#
#       prob_to_read_share_unilist_luxemburg  \
# 946                                    0.0
# 1288                                   0.0
# 2848                                   0.0
# 9102                                   0.0
# 9195                                   0.0
#
#       prob_to_read_sum_unilist_graz_2021  ...  wiki_page_found  \
# 946                                  0.0  ...             True
# 1288                                 0.0  ...            False
# 2848                                 0.0  ...             True
# 9102                                 0.0  ...            False
# 9195                                 0.0  ...            False
#
#                                      wiki_page_url  wiki_page_title  \
# 946    https://de.wikipedia.org/wiki/Elias_Hirschl    Elias Hirschl
# 1288                                           NaN              NaN
# 2848  https://de.wikipedia.org/wiki/Greta_Thunberg   Greta Thunberg
# 9102                                           NaN              NaN
# 9195                                           NaN              NaN
#
#       wiki_item_id  wiki_length_in_words  wiki_number_of_sitelinks  \
# 946      Q28984731                1731.0                       2.0
# 1288           NaN                   0.0                       0.0
# 2848     Q56434717               13918.0                     145.0
# 9102           NaN                   0.0                       0.0
# 9195           NaN                   0.0                       0.0
#
#       wiki_number_of_pageviews_last_5_years  wiki_number_of_in_links  \
# 946                                 48402.0                     34.0
# 1288                                    0.0                      0.0
# 2848                              2459970.0                    428.0
# 9102                                    0.0                      0.0
# 9195                                    0.0                      0.0
#
#       BDSL_searchphrase  BDSL_hits_2000_all
# 946       Elias Hirschl                 6.0
# 1288     Kristin Höller                 1.0
# 2848     Greta Thunberg                 2.0
# 9102      Asin Andkohiy                 1.0
# 9195        Ibrahim Bah                 0.0
#
# [5 rows x 144 columns]

# %%
# gnd_occupations = data['GND_occupation'].dropna().tolist()
# gnd_occupations = [x.split(' + ') for x in gnd_occupations]
# gnd_occupations = [item for sublist in gnd_occupations for item in sublist]
# pd.Series(gnd_occupations).value_counts().to_csv("gnd_occupations.csv")

# %%
data.to_csv("../data/data.csv")
