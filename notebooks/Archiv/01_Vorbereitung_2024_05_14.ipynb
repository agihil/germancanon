# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import plotly.express as px
import regex as re

from tqdm.notebook import tqdm

# %%
test_links = [
    'https://d-nb.info/gnd/118500856', # Aeschylus
    'https://d-nb.info/gnd/118501232', # Aichinger
    'https://d-nb.info/gnd/118505602', # Bachmann
    'https://d-nb.info/gnd/118516906', # Büchner
    'https://d-nb.info/gnd/118519859', # Celan
    'https://d-nb.info/gnd/118527908', # Dürrenmatt
]

# %% [markdown]
# # Leselisten

# %%
mode = 'gewichtet'

# %%
leselisten_titles = pd.read_csv("/content/drive/MyDrive/2024.Kanonizität/resources/01_leselisten.csv", sep = ";")

# %%
leselisten_titles = leselisten_titles.query("GND.notna()")

# %%
leselisten_titles.head()
# Out:
#                    Autor                               GND Geschlecht  \
# 0   $Bahr, Ehrhard (Hg.)   https://d-nb.info/gnd/130674966        NaN
# 1     $Beers, Anna (Hg.)  https://d-nb.info/gnd/1023005093        NaN
# 2  $Behrens, Katja (Hg.)   https://d-nb.info/gnd/124718124        NaN
# 3    $Bender, Hans (Hg.)   https://d-nb.info/gnd/118508849        NaN
# 4   $Best, Otto F. (Hg.)   https://d-nb.info/gnd/116155086        NaN
#
#                                             Titel Jahreszahl  \
# 0     Was ist Aufklärung? Thesen und Definitionen       1974
# 1  Frauen / Lyrik. Gedichte in deutscher Sprache        2020
# 2                       Frauenbriefe der Romantik       1982
# 3                    Deutsche Gedichte: 1930-1960       1983
# 4                     Theorie des Expressionismus       1986
#
#    Jahreszahl_Statistik              Gattung Modul_Zeit_vor_17.Jh.  \
# 0                1974.0  Poetik / Essayistik                   NaN
# 1                2020.0                Lyrik                   NaN
# 2                1982.0            Sonstiges                   NaN
# 3                1983.0                Lyrik                   NaN
# 4                1986.0  Poetik / Essayistik                   NaN
#
#   Modul_Sprache_(international) Modul_KJL  ... Salzburg Stuttgart  \
# 0                           NaN       NaN  ...      NaN       NaN
# 1                           NaN       NaN  ...      NaN       NaN
# 2                           NaN       NaN  ...      NaN       NaN
# 3                           NaN       NaN  ...      NaN       NaN
# 4                           NaN       NaN  ...      NaN       NaN
#
#    Stuttgart 2022  Trier Tübingen Wien Wuppertal  Würzburg  Würzburg_2019  \
# 0             NaN    NaN      NaN  NaN       NaN       NaN            NaN
# 1             1.0    NaN      NaN  NaN       NaN       NaN            NaN
# 2             NaN    NaN      NaN  NaN       NaN       NaN            NaN
# 3             NaN    NaN      NaN  NaN       NaN       NaN            NaN
# 4             NaN    NaN      NaN  NaN       NaN       NaN            NaN
#
#   Zürich
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 52 columns]

# %%
leselisten_titles['Autor'] = [x.rstrip() if pd.notna(x) else float('NaN') for x in leselisten_titles['Autor']]
leselisten_titles['Jahreszahl_Statistik'] = leselisten_titles['Jahreszahl_Statistik'].astype(float)

# %%
leselisten_titles = leselisten_titles.rename(columns = {
    'Modul_Zeit_vor_17.Jh.' : 'Modul_Zeit',
    'Modul_Sprache_(international)' : 'Modul_Sprache',
    'Modul: KJL' : 'Modul_KJL',
})

# %%
leselisten_dict = {
    'Aachen' : 'Aachen1',
    'Berlin' : 'FU Berlin',
    'Innsbruck' : 'Innsbruck1',
    'Innsbruck 2023' : 'Innsbruck2',
    'Köln Fundamentum' : 'Köln',
    'LA Aachen' : 'Aachen2',
    'Stuttgart' : 'Stuttgart1',
    'Stuttgart 2022' : 'Stuttgart2',
    'Würzburg' : 'Würzburg1',
    'Würzburg_2019' : 'Würzburg2',
}

leselisten_titles = leselisten_titles.rename(columns=leselisten_dict)

# %%
exceptions = [
    'Autor', 'GND', 'Geschlecht', 'Titel', 'Jahreszahl', 'Jahreszahl_Statistik', 'Gattung',
    'Modul_Zeit', 'Modul_Sprache', 'Modul_KJL', 'Dekade', 'Jahrhundert', 'sum'
]
leselisten = [x for x in leselisten_titles.columns.tolist() if x not in exceptions]

# %%
def convert_to_float(frac_str):
    if type(frac_str) == str:
        frac_str = re.sub(",", ".", frac_str)
    try:
        return float(frac_str)
    except ValueError:
        frac_str = re.sub("⁄", "/", frac_str)
        num, denom = frac_str.split('/')
        try:
            leading, num = num.split(' ')
            whole = float(leading)
        except ValueError:
            whole = 0
        frac = float(num) / float(denom)
        return whole - frac if whole < 0 else whole + frac

leselisten_titles[leselisten] = leselisten_titles[leselisten].applymap(convert_to_float)

# %%
# in Zahlen konvertieren
leselisten_titles[leselisten] = leselisten_titles[leselisten].astype(float)

# alles über 0 auf 1 setzen;
# auskommentiert für gewichtet, nicht auskommentiert für ungewichtet
if mode == 'ungewichtet':
    leselisten_titles[leselisten] = leselisten_titles[leselisten].notnull().astype('int')

# NaN mit 0 ersetzen
leselisten_titles[leselisten] = leselisten_titles[leselisten].fillna(0)

# Texte ausschließen, die mit $ beginnen (Anthologien)
leselisten_titles = leselisten_titles[~leselisten_titles['Autor'].str.startswith('$', na = False)]

# %%
leselisten_authors = pd.DataFrame()
leselisten_authors.index = leselisten_titles.drop_duplicates(subset='GND').sort_values(by='GND')['GND']
leselisten_authors['Leselisten_Autor'] = leselisten_titles.drop_duplicates(subset='GND').sort_values(by='GND')['Autor'].tolist()
leselisten_authors[['Leselisten_'+x for x in leselisten]] = leselisten_titles.sort_values(by='GND').groupby('GND')[leselisten].sum()

# %%
leselisten_authors.loc[test_links][[
    'Leselisten_Autor',
    'Leselisten_Göttingen', 'Leselisten_Würzburg1',
]]
# Out:
#                                       Leselisten_Autor  Leselisten_Göttingen  \
# GND
# https://d-nb.info/gnd/118500856              Aischylos                   0.0
# https://d-nb.info/gnd/118501232        Aichinger, Ilse                   0.0
# https://d-nb.info/gnd/118505602     Bachmann, Ingeborg                   1.0
# https://d-nb.info/gnd/118516906         Büchner, Georg                   2.0
# https://d-nb.info/gnd/118519859            Celan, Paul                   0.0
# https://d-nb.info/gnd/118527908  Dürrenmatt, Friedrich                   1.0
#
#                                  Leselisten_Würzburg1
# GND
# https://d-nb.info/gnd/118500856                   3.0
# https://d-nb.info/gnd/118501232                   0.0
# https://d-nb.info/gnd/118505602                   2.0
# https://d-nb.info/gnd/118516906                   3.0
# https://d-nb.info/gnd/118519859                   3.0
# https://d-nb.info/gnd/118527908                   1.0

# %%
leselisten_authors.shape
# Out:
# (180, 43)

# %% [markdown]
# # Schule

# %%
schule_titles = pd.read_csv("/content/drive/MyDrive/2024.Kanonizität/resources/02_schule.csv", sep=";")

# %%
schule_titles = schule_titles.query("GND.notna()")

# %%
schule_titles.head()
# Out:
#      ID         Bundesland Nachname                              GND  \
# 0  2508  Baden-Württemberg     Äsop  https://d-nb.info/gnd/118647180
# 1  2447     Sachsen-Anhalt     Äsop  https://d-nb.info/gnd/118647180
# 2  1778  Baden-Württemberg   Achebe  https://d-nb.info/gnd/118646680
# 3   297             Hessen      Ade  https://d-nb.info/gnd/138053669
# 4     3            Hamburg      Ade  https://d-nb.info/gnd/138053669
#
#   Geschlecht                         Titel Erscheinungsjahr  \
# 0   männlich                        Fabeln        unbekannt
# 1   männlich                        Fabeln        unbekannt
# 2   männlich  Okonkwo oder Das Alte stürzt             1959
# 3   weiblich           Toni Erdmann (Film)             2016
# 4   weiblich           Toni Erdmann (Film)             2016
#
#   Erscheinungsjahr_k                         Lit.preis_Name  \
# 0          unbekannt                                    NaN
# 1          unbekannt                                    NaN
# 2               1958                                    NaN
# 3               2017  (mehrere Filmpreise, siehe Wikipedia)
# 4               2016  (mehrere Filmpreise, siehe Wikipedia)
#
#   Lit.preis_Autor_in_Name Jug.literatur
# 0                     NaN          nein
# 1                     NaN          nein
# 2                     NaN          nein
# 3                     NaN            ja
# 4                     NaN            ja

# %%
schule_authors = pd.DataFrame()

for gnd_link in schule_titles['GND'].unique():
  meta_author = schule_titles.query("GND == @gnd_link")
  schule_authors.loc[gnd_link, 'Schule_Autor'] = meta_author['Nachname'].tolist()[0]
  for bundesland in meta_author['Bundesland']:
    meta_author_bundesland = meta_author.query("Bundesland == @bundesland")
    schule_authors.loc[gnd_link, 'Schule_'+bundesland] = meta_author_bundesland.shape[0]

schule_authors = schule_authors.fillna(0)

# %%
schule_authors.loc[test_links][[
    'Schule_Autor',
    'Schule_Niedersachsen', 'Schule_Bayern',
]]
# Out:
#                                 Schule_Autor  Schule_Niedersachsen  \
# https://d-nb.info/gnd/118500856    Aischylos                   0.0
# https://d-nb.info/gnd/118501232    Aichinger                   1.0
# https://d-nb.info/gnd/118505602     Bachmann                   2.0
# https://d-nb.info/gnd/118516906      Büchner                   4.0
# https://d-nb.info/gnd/118519859        Celan                   1.0
# https://d-nb.info/gnd/118527908   Dürrenmatt                   5.0
#
#                                  Schule_Bayern
# https://d-nb.info/gnd/118500856            0.0
# https://d-nb.info/gnd/118501232            0.0
# https://d-nb.info/gnd/118505602            1.0
# https://d-nb.info/gnd/118516906            1.0
# https://d-nb.info/gnd/118519859            1.0
# https://d-nb.info/gnd/118527908            6.0

# %%
schule_authors.shape
# Out:
# (128, 13)

# %% [markdown]
# # Merge Leselisten + Schule

# %%
all_authors = leselisten_authors.join(schule_authors, how='outer')

# %%
fill_columns = [x for x in all_authors.columns if '_Autor' not in x]
all_authors[fill_columns] = all_authors[fill_columns].fillna(0)

# %%
all_authors.shape
# Out:
# (247, 56)

# %%
all_authors.query("Leselisten_Autor.notna() and Schule_Autor.notna()").shape
# Out:
# (61, 56)

# %%
all_authors.loc[test_links][[
    'Leselisten_Autor', 'Schule_Autor',
    'Leselisten_Göttingen', 'Leselisten_Würzburg1',
    'Schule_Niedersachsen', 'Schule_Bayern',
]]
# Out:
#                                       Leselisten_Autor Schule_Autor  \
# https://d-nb.info/gnd/118500856              Aischylos    Aischylos
# https://d-nb.info/gnd/118501232        Aichinger, Ilse    Aichinger
# https://d-nb.info/gnd/118505602     Bachmann, Ingeborg     Bachmann
# https://d-nb.info/gnd/118516906         Büchner, Georg      Büchner
# https://d-nb.info/gnd/118519859            Celan, Paul        Celan
# https://d-nb.info/gnd/118527908  Dürrenmatt, Friedrich   Dürrenmatt
#
#                                  Leselisten_Göttingen  Leselisten_Würzburg1  \
# https://d-nb.info/gnd/118500856                   0.0                   3.0
# https://d-nb.info/gnd/118501232                   0.0                   0.0
# https://d-nb.info/gnd/118505602                   1.0                   2.0
# https://d-nb.info/gnd/118516906                   2.0                   3.0
# https://d-nb.info/gnd/118519859                   0.0                   3.0
# https://d-nb.info/gnd/118527908                   1.0                   1.0
#
#                                  Schule_Niedersachsen  Schule_Bayern
# https://d-nb.info/gnd/118500856                   0.0            0.0
# https://d-nb.info/gnd/118501232                   1.0            0.0
# https://d-nb.info/gnd/118505602                   2.0            1.0
# https://d-nb.info/gnd/118516906                   4.0            1.0
# https://d-nb.info/gnd/118519859                   1.0            1.0
# https://d-nb.info/gnd/118527908                   5.0            6.0

# %% [markdown]
# # GND

# %% [markdown]
# ### Scrape

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
def get_response_from_gnd (gnd_url):
    return requests.get(gnd_url)

# %%
def get_name_from_gnd_response (response):
    preferred_name_start = response.text.find('gndo:preferredNameEntityForThePerson')
    preferred_name_slice = response.text[preferred_name_start:preferred_name_start+300]

    forename = ''
    surname = ''

    forename_start = preferred_name_slice.find("gndo:forename")
    if forename_start != -1:
      forename_slice = preferred_name_slice[(forename_start + 15):(forename_start + 100)]
      forename = re.findall(""".+?(?=\")""", forename_slice)[0]

    prefix_start = preferred_name_slice.find("gndo:prefix")
    if prefix_start != -1:
      prefix_slice = preferred_name_slice[(prefix_start + 13):(prefix_start + 100)]
      prefix = re.findall(""".+?(?=\")""", prefix_slice)[0]
      forename = forename + ' ' + prefix

    surname_start = preferred_name_slice.find("gndo:surname")
    if surname_start != -1:
      surname_slice = preferred_name_slice[(surname_start + 14):(surname_start + 100)]
      surname = re.findall(""".+?(?=\")""", surname_slice)[0]

    personalname_start = preferred_name_slice.find("gndo:personalName")
    if personalname_start != -1:
      personalname_slice = preferred_name_slice[(personalname_start + 19):(personalname_start + 100)]
      personalname = re.findall(""".+?(?=\")""", personalname_slice)[0]
      surname = personalname

    nameaddition_start = preferred_name_slice.find("gndo:nameAddition")
    if nameaddition_start != -1:
      nameaddition_slice = preferred_name_slice[(nameaddition_start + 19):(nameaddition_start + 100)]
      nameaddition = re.findall(""".+?(?=\")""", nameaddition_slice)[0]
      surname = surname + ' ' + nameaddition

    return [forename, surname]

# %%
def get_gender_from_gnd_response (response):
    gender = float('nan')

    gender_pos_start = response.text.find('vocab/gnd/gender#')
    gender_content = response.text[gender_pos_start+17:gender_pos_start+23]

    if 'female' in gender_content:
        gender = 'female'
    elif 'male' in gender_content:
        gender = 'male'
    else:
        gender = gender_content

    return gender

# %%
def get_lifetime_from_gnd_response (response):
    lifetime = [float('nan'), float('nan')]

    birth_pos = response.text.find('gndo:dateOfBirth ')
    if birth_pos != -1:
        birth_content = response.text[birth_pos+18:birth_pos+22]
        if birth_content.isnumeric():
            lifetime[0] = int(birth_content)

    death_pos = response.text.find('gndo:dateOfDeath ')
    if death_pos != -1:
        death_content = response.text[death_pos+18:death_pos+22]
        if death_content.isnumeric():
            lifetime[1] = int(death_content)

    return lifetime

# %%
def get_countries_from_gnd_response (response):
    countries = float('nan')

    soup = BeautifulSoup(response.text, "html.parser")
    td_elements = soup.findAll('td')

    for i, td_element in enumerate(td_elements):
        if td_element.strong != None and td_element.strong.string == 'Land':
            countries = td_elements[i+1].string.strip()
            countries = countries.split('; ')

    return countries

# %%
def get_occupations_from_gnd_response (response):
    occupations = float('nan')

    soup = BeautifulSoup(response.text, "html.parser")
    td_elements = soup.findAll('td')

    for i, td_element in enumerate(td_elements):
        if td_element.strong != None and td_element.strong.string == 'Beruf(e)':
            occupation_links = td_elements[i+1].findAll('a')
            occupations = [x.string for x in occupation_links]

            if len(occupations) == 0: # gibt Rubrik Beruf(e), aber dort keine Links, sondern plain text
                occupations = [td_elements[i+1].string.strip()]

    return occupations

# %%
gnd = pd.DataFrame()

for gnd_link in tqdm(all_authors.index):
  # response_a = get_response_from_gnd(gnd_url)
  response_b = get_response_from_gnd(gnd_link + '/about/lds')

  forename, surname = get_name_from_gnd_response(response_b)
  if surname == '':
    print(f"{gnd_link} Fehler (Name)")
    author_name = float('NaN')
  elif forename != '':
    author_name = surname + ', ' + forename
  else:
    author_name = surname
  gnd.at[gnd_link, 'GND_Autor'] = author_name

  gnd.at[gnd_link, 'GND_Gender'] = get_gender_from_gnd_response(response_b)
  gnd.at[gnd_link, 'GND_Geburtsjahr'] = get_lifetime_from_gnd_response(response_b)[0]
  gnd.at[gnd_link, 'GND_Sterbejahr'] = get_lifetime_from_gnd_response(response_b)[1]
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]

# %%
gnd = gnd.sort_values(by = 'GND_Autor')

gnd['GND_Autor'] = [re.sub('ä', 'ä', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('á', 'á', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('Č', 'Č', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('ć', 'ć', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('é', 'é', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('ë', 'ë', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('Ō', 'Ō', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('Ö', 'Ö', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('ö', 'ö', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('ó', 'ó', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('ō', 'ō', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('ü', 'ü', x) if pd.notna(x) else x for x in gnd['GND_Autor']]
gnd['GND_Autor'] = [re.sub('ž', 'z', x) if pd.notna(x) else x for x in gnd['GND_Autor']]

# %%
gnd.to_csv("/content/drive/MyDrive/2024.Kanonizität/resources/00_gnd.csv")

# %% [markdown]
# ### Import and Merge

# %%
gnd = pd.read_csv("/content/drive/MyDrive/2024.Kanonizität/resources/00_gnd.csv", index_col = [0])

# %%
for this_index in all_authors.index:
  if this_index in gnd.index:
    all_authors.at[this_index, 'GND_Autor'] = gnd.at[this_index, 'GND_Autor']
    all_authors.at[this_index, 'GND_Gender'] = gnd.at[this_index, 'GND_Gender']
    all_authors.at[this_index, 'GND_Geburtsjahr'] = gnd.at[this_index, 'GND_Geburtsjahr']
    all_authors.at[this_index, 'GND_Sterbejahr'] = gnd.at[this_index, 'GND_Sterbejahr']

# %%
all_authors.loc[test_links][[
    'Leselisten_Autor', 'Schule_Autor', 'GND_Autor'
]]
# Out:
#                                       Leselisten_Autor Schule_Autor  \
# https://d-nb.info/gnd/118500856              Aischylos    Aischylos
# https://d-nb.info/gnd/118501232        Aichinger, Ilse    Aichinger
# https://d-nb.info/gnd/118505602     Bachmann, Ingeborg     Bachmann
# https://d-nb.info/gnd/118516906         Büchner, Georg      Büchner
# https://d-nb.info/gnd/118519859            Celan, Paul        Celan
# https://d-nb.info/gnd/118527908  Dürrenmatt, Friedrich   Dürrenmatt
#
#                                              GND_Autor
# https://d-nb.info/gnd/118500856              Aeschylus
# https://d-nb.info/gnd/118501232        Aichinger, Ilse
# https://d-nb.info/gnd/118505602     Bachmann, Ingeborg
# https://d-nb.info/gnd/118516906         Büchner, Georg
# https://d-nb.info/gnd/118519859            Celan, Paul
# https://d-nb.info/gnd/118527908  Dürrenmatt, Friedrich

# %%
# Gibt es Autor:innen mit unterschiedlichen GND-Links, die den gleichen GND-Namen haben?
all_authors['GND_Autor'].value_counts()[all_authors['GND_Autor'].value_counts() > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # Wikipedia

# %% [markdown]
# ### Scrape

# %%
# !pip3 install tools
# !pip install pywikibot

# %%
# Code (leicht angepasst) nach: https://github.com/temporal-communities/wiki-metrix

# Illmer, V. J., Soethaert, B., Welz, L., Fischer, F., & Jäschke, R. (2024, Februar 21).
# Literatur im Wikiversum – Eine praktische Annäherung über API-Abfragen und Wikipedia-Metriken.
# DHd 2024 Quo Vadis DH (DHd2024), Passau, Deutschland. https://doi.org/10.5281/zenodo.10698426

pywikibot_config = r"""# -*- coding: utf-8  -*-


mylang = 'de'
family = 'wikipedia'
usernames['wikipedia']['de'] = 'test'"""

with open('user-config.py', 'w', encoding="utf-8") as f:
    f.write(pywikibot_config)

import pywikibot
import requests
import datetime
import urllib.parse

def get_page_stats(page: pywikibot.Page):
    """
    Get page stats for a given page.
    """

    # Handle redirects
    # page = handle_redirect(page)

    page_content = page.get(force=True)
    length_in_bytes = len(page_content.encode("utf-8"))
    page_revisions = list(page.revisions(reverse=True))

    data = {
        "title": page.title(),
        "url": page.full_url(),
        "length": length_in_bytes,
        "n_contributors": len(page.contributors()),
        "n_revisions": len(page_revisions),
        "n_extlinks": len(list(page.extlinks())),
        "n_langlinks": len(page.langlinks()),
        "n_links": len(list(page.linkedPages())),
        "n_linkshere": len(
            list(page.linkedPages(namespaces=[0], follow_redirects=False))
        ),  # Article namespace only (0)
        "n_categories": len(list(page.categories())),
        "pageviews_365d": get_pageviews(page, days=365),
        "pageviews_730d": get_pageviews(page, days=730),
        "pageviews_1825d": get_pageviews(page, days=1825),
        "first_revision": page_revisions[0].timestamp,
    }

    MW_API_LIMIT = 500
    # Give warning if any value is at the limit
    for key, value in data.items():
        if value == MW_API_LIMIT:
            print(f"Warning: {key} at limit {MW_API_LIMIT}.")

    return data

# Use Wikimedia Pageviews REST API to get pageviews
def get_pageviews(page: pywikibot.Page, days=365):
    lang = page.site.code
    site = page.site.family.name

    # Wikimedia REST API
    # https://wikitech.wikimedia.org/wiki/Analytics/AQS/Pageviews
    # https://wikimedia.org/api/rest_v1/
    end_date = datetime.date.today() - datetime.timedelta(days=2)  # Two days ago
    start_date = end_date - datetime.timedelta(days=days)  # Two days minus [days] ago

    agent_type = "user"  # user, bot, spider, all-agents
    title_uri = urllib.parse.quote(
        page.title(underscore=True, with_section=False), safe=""
    )  # URI-encoded title, no safe characters
    url = f"https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/{lang}.{site}/all-access/{agent_type}/{title_uri}/monthly/{start_date.strftime('%Y%m%d')}/{end_date.strftime('%Y%m%d')}"

    user_agent = f"wiki-metrix (https://github.com/temporal-communities/wiki-metrix) requests/{requests.__version__}"
    response = requests.get(url, headers={"User-Agent": user_agent})

    if response.status_code != 200:
        raise Exception(f"Error: {response.status_code} {response.reason}")

    data = response.json()
    pageviews_sum = sum(filter(None, [item["views"] for item in data["items"]]))

    return pageviews_sum

def add_page_stats_to_df (df, wikipedia_article_column = 'Wikipedia_Artikel'):
    site = pywikibot.Site('de', 'wikipedia')  # The site we want to run our bot on
    wikiresults_joined_df = pd.DataFrame()

    for article in tqdm(df[wikipedia_article_column]):
        page = pywikibot.Page(site, article)
        wikiresults = get_page_stats(page)

        wikiresults_df = pd.DataFrame(pd.Series(wikiresults)).T
        wikiresults_joined_df = pd.concat([wikiresults_joined_df, wikiresults_df])

    wikiresults_joined_df = wikiresults_joined_df.reset_index(drop=True)
    df = df.join(wikiresults_joined_df)

    return df

# %%
site = pywikibot.Site('de', 'wikipedia')

# %%
wiki = pd.DataFrame()

for gnd_link in tqdm(all_authors.sort_values(by='GND_Autor').index):

  author = all_authors.loc[gnd_link, 'GND_Autor']
  if pd.isna(author):
    author = '(nan) XXX'
  author_reversed = ' '.join(str(author).split(', ')[::-1])

  page = pywikibot.Page(site, author_reversed)

  try:
    wiki_author = get_page_stats(page)
    wiki_author['GND_Autor'] = author
    wiki_author['wiki_status'] = 'page_found'
    wiki_author = pd.DataFrame(pd.Series(wiki_author)).T
    wiki_author.index = [gnd_link]
  except:
    wiki_author = pd.DataFrame(index = [gnd_link])
    wiki_author['GND_Autor'] = author
    wiki_author['wiki_status'] = 'page_not_found'
    wiki_author['pageviews_365d'] = 0

  if wiki_author['wiki_status'].tolist()[0] == 'page_not_found':
    print(f"{gnd_link} {author} (Seite nicht gefunden)")
  else:
    print(f"{gnd_link} {author} ({wiki_author['pageviews_365d'].tolist()[0]} pageviews)")

  wiki = pd.concat([wiki, wiki_author])
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pywikibot/page/_links.py:608: UserWarning: Site wikipedia:no instantiated using different code "nb"
#   link._site = pywikibot.Site(lang, source.family.name)
# https://d-nb.info/gnd/118646680 Achebe, Chinua (9578 pageviews)
# https://d-nb.info/gnd/119369125 Achleitner, Friedrich (3609 pageviews)
# https://d-nb.info/gnd/118500422 Achternbusch, Herbert (14083 pageviews)
# https://d-nb.info/gnd/138053669 Ade, Maren (26956 pageviews)
# https://d-nb.info/gnd/118500775 Adorno, Theodor W. (168277 pageviews)
# https://d-nb.info/gnd/118500856 Aeschylus (Seite nicht gefunden)
# https://d-nb.info/gnd/118647180 Aesopus (265 pageviews)
# https://d-nb.info/gnd/119293439 Agamben, Giorgio (17610 pageviews)
# https://d-nb.info/gnd/118501232 Aichinger, Ilse (31821 pageviews)
# https://d-nb.info/gnd/118501259 Ajtmatov, Čingiz (Seite nicht gefunden)
# https://d-nb.info/gnd/118501380 Albee, Edward (5754 pageviews)
# https://d-nb.info/gnd/119604108 Alciato, Andreas (Seite nicht gefunden)
# /usr/local/lib/python3.10/dist-packages/pywikibot/page/_links.py:608: UserWarning: Site wikipedia:be-tarask instantiated using different code "be-x-old"
#   link._site = pywikibot.Site(lang, source.family.name)
# https://d-nb.info/gnd/1256774294 Alighieri, Dante (164514 pageviews)
# https://d-nb.info/gnd/118869159 Allende, Isabel (93330 pageviews)
# https://d-nb.info/gnd/123526183 Almond, David (998 pageviews)
# https://d-nb.info/gnd/118502255 Altenberg, Peter (19032 pageviews)
# https://d-nb.info/gnd/115674861 Altenburg, Matthias (5154 pageviews)
# https://d-nb.info/gnd/118937197 Amery, Carl (9443 pageviews)
# https://d-nb.info/gnd/118502786 Andersch, Alfred (29942 pageviews)
# https://d-nb.info/gnd/118502794 Andersen, Hans Christian (184724 pageviews)
# https://d-nb.info/gnd/119111365 Anderson, Sascha (27080 pageviews)
# https://d-nb.info/gnd/118502921 Andreas-Salomé, Lou (74414 pageviews)
# https://d-nb.info/gnd/118502956 Andres, Stefan (8736 pageviews)
# https://d-nb.info/gnd/118503111 Angelus Silesius (23309 pageviews)
# https://d-nb.info/gnd/120315106 Ani, Friedrich (13507 pageviews)
# https://d-nb.info/gnd/118503251 Anouilh, Jean (9157 pageviews)
# https://d-nb.info/gnd/11850357X Anzengruber, Ludwig (10239 pageviews)
# https://d-nb.info/gnd/118829637 Apitz, Bruno (15235 pageviews)
# https://d-nb.info/gnd/11850374X Apuleius Madaurensis (Seite nicht gefunden)
# https://d-nb.info/gnd/1188043420 Arb, Nando von (Seite nicht gefunden)
# https://d-nb.info/gnd/11850391X Arendt, Hannah (283907 pageviews)
# https://d-nb.info/gnd/118650130 Aristoteles (242592 pageviews)
# https://d-nb.info/gnd/118184555 Arjouni, Jakob (11245 pageviews)
# https://d-nb.info/gnd/118504177 Arnim, Achim von (29569 pageviews)
# https://d-nb.info/gnd/118504185 Arnim, Bettina von (53759 pageviews)
# https://d-nb.info/gnd/118504398 Arp, Hans (39366 pageviews)
# https://d-nb.info/gnd/11850441X Arrabal, Fernando (2861 pageviews)
# https://d-nb.info/gnd/118504495 Artaud, Antonin (14885 pageviews)
# https://d-nb.info/gnd/118504533 Artmann, H. C. (13836 pageviews)
# https://d-nb.info/gnd/120430991 Asscher-Pinkhof, Clara (836 pageviews)
# https://d-nb.info/gnd/11805077X Assmann, Jan (54586 pageviews)
# https://d-nb.info/gnd/118650769 Aston, Louise (7329 pageviews)
# https://d-nb.info/gnd/118646168 Atwood, Margaret (48343 pageviews)
# https://d-nb.info/gnd/11865103X Auerbach, Berthold (7750 pageviews)
# https://d-nb.info/gnd/118505025 Auerbach, Erich (6296 pageviews)
# https://d-nb.info/gnd/115699635 Augstburger, Urs (558 pageviews)
# https://d-nb.info/gnd/118829211 Ausländer, Rose (30954 pageviews)
# https://d-nb.info/gnd/118505173 Austen, Jane (206754 pageviews)
# https://d-nb.info/gnd/11910251X Auster, Paul (214494 pageviews)
# https://d-nb.info/gnd/119025698 Ava Frau (Seite nicht gefunden)
# https://d-nb.info/gnd/120841916 Babendererde, Antje (3562 pageviews)
# https://d-nb.info/gnd/12493272X Bach, Tamara (3358 pageviews)
# https://d-nb.info/gnd/118505602 Bachmann, Ingeborg (394707 pageviews)
# https://d-nb.info/gnd/118505653 Bachtin, Michail Michajlovič (Seite nicht gefunden)
# https://d-nb.info/gnd/118505955 Bahr, Hermann (13324 pageviews)
# https://d-nb.info/gnd/118506234 Ball, Hugo (22719 pageviews)
# https://d-nb.info/gnd/118506358 Balzac, Honoré de (69597 pageviews)
# https://d-nb.info/gnd/115743030 Baricco, Alessandro (6920 pageviews)
# https://d-nb.info/gnd/118506617 Barlach, Ernst (44811 pageviews)
# https://d-nb.info/gnd/1095775561 Barthel, Kurt (5600 pageviews)
# https://d-nb.info/gnd/118506862 Barthes, Roland (30155 pageviews)
# https://d-nb.info/gnd/118507184 Baudelaire, Charles (43960 pageviews)
# https://d-nb.info/gnd/124462316 Bauer, Marion Dane (131 pageviews)
# https://d-nb.info/gnd/133528650 Bauer, Michael Gerard (3017 pageviews)
# https://d-nb.info/gnd/118507397 Bauer, Wolfgang (377 pageviews)
# https://d-nb.info/gnd/128366974 Bauersima, Igor (2024 pageviews)
# https://d-nb.info/gnd/1016386486 Baum, Antonia (11822 pageviews)
# https://d-nb.info/gnd/118653830 Baum, Vicki (26228 pageviews)
# https://d-nb.info/gnd/118507605 Baumgarten, Alexander Gottlieb (7265 pageviews)
# https://d-nb.info/gnd/118507753 Bayer, Konrad (4193 pageviews)
# https://d-nb.info/gnd/118507877 Beauvoir, Simone de (130618 pageviews)
# https://d-nb.info/gnd/118507931 Becher, Johannes Robert (Seite nicht gefunden)
# https://d-nb.info/gnd/118654292 Bechstein, Ludwig (20337 pageviews)
# https://d-nb.info/gnd/118829742 Becker, Jurek (37145 pageviews)
# https://d-nb.info/gnd/118508091 Becker, Jürgen (1460 pageviews)
# https://d-nb.info/gnd/118508172 Beckett, Samuel (75057 pageviews)
# https://d-nb.info/gnd/118508253 Beer, Johann (1713 pageviews)
# https://d-nb.info/gnd/118654756 Beer-Hofmann, Richard (4054 pageviews)
# https://d-nb.info/gnd/115371915 Begley, Louis (7839 pageviews)
# https://d-nb.info/gnd/120555573 Bekker, Alfred (4809 pageviews)
# https://d-nb.info/gnd/118509039 Benjamin, Walter (144309 pageviews)
# https://d-nb.info/gnd/118509047 Benn, Gottfried (83644 pageviews)
# https://d-nb.info/gnd/124742823 Berg, Sibylle (106877 pageviews)
# https://d-nb.info/gnd/11850939X Bergengruen, Werner (18607 pageviews)
# https://d-nb.info/gnd/118509578 Bergson, Henri (26822 pageviews)
# https://d-nb.info/gnd/133565777 Berkenheger, Susanne (216 pageviews)
# https://d-nb.info/gnd/119150026 Berkéwicz, Ulla (6380 pageviews)
# https://d-nb.info/gnd/118509861 Bernhard, Thomas (113114 pageviews)
# https://d-nb.info/gnd/129738387 Bertram, Rüdiger (5823 pageviews)
# https://d-nb.info/gnd/124932479 Bessing, Joachim (1961 pageviews)
# https://d-nb.info/gnd/11548048X Beyer, Marcel (7915 pageviews)
# https://d-nb.info/gnd/118510649 Bichsel, Peter (19357 pageviews)
# https://d-nb.info/gnd/119621290 Bidermann, Jakob (1351 pageviews)
# https://d-nb.info/gnd/118510754 Bienek, Horst (6185 pageviews)
# https://d-nb.info/gnd/118510789 Biermann, Wolf (208388 pageviews)
# https://d-nb.info/gnd/12126582X Biller, Maxim (68696 pageviews)
# https://d-nb.info/gnd/118511270 Birken, Sigmund von (2791 pageviews)
# https://d-nb.info/gnd/136059201 Bjerg, Bov (11438 pageviews)
# https://d-nb.info/gnd/119025701 Blankenburg, Christian Friedrich von (Seite nicht gefunden)
# https://d-nb.info/gnd/111492167X Bleidiek, Thomas (Seite nicht gefunden)
# https://d-nb.info/gnd/118511742 Bloch, Ernst (52987 pageviews)
# https://d-nb.info/gnd/118511963 Blumauer, Alois (Seite nicht gefunden)
# https://d-nb.info/gnd/118664123 Blumenberg, Hans (21722 pageviews)
# https://d-nb.info/gnd/118512161 Bobrowski, Johannes (10032 pageviews)
# https://d-nb.info/gnd/11851217X Boccaccio, Giovanni (31577 pageviews)
# https://d-nb.info/gnd/118512315 Bodmer, Johann Jakob (5608 pageviews)
# https://d-nb.info/gnd/12363816X Bodrozić, Marica (Seite nicht gefunden)
# https://d-nb.info/gnd/119501252 Boie, Kirsten (29640 pageviews)
# https://d-nb.info/gnd/118661175 Boldt, Paul (2847 pageviews)
# https://d-nb.info/gnd/118513435 Borchardt, Rudolf (11168 pageviews)
# https://d-nb.info/gnd/118513451 Borchert, Wolfgang (126056 pageviews)
# https://d-nb.info/gnd/118513532 Borges, Jorge Luis (46890 pageviews)
# https://d-nb.info/gnd/11851363X Born, Nicolas (4844 pageviews)
# https://d-nb.info/gnd/118513931 Bote, Hermann (2489 pageviews)
# https://d-nb.info/gnd/118810758 Bourdieu, Pierre (70386 pageviews)
# https://d-nb.info/gnd/119520478 Boyle, T. Coraghessan (Seite nicht gefunden)
# https://d-nb.info/gnd/133252922 Boyne, John (23473 pageviews)
# https://d-nb.info/gnd/118659723 Bradbury, Ray (33856 pageviews)
# https://d-nb.info/gnd/119422999 Brambach, Rainer (1537 pageviews)
# https://d-nb.info/gnd/118514512 Brasch, Thomas (135195 pageviews)
# https://d-nb.info/gnd/118514644 Braun, Volker (14989 pageviews)
# https://d-nb.info/gnd/118514768 Brecht, Bertolt (380101 pageviews)
# https://d-nb.info/gnd/118514776 Bredel, Willi (7066 pageviews)
# https://d-nb.info/gnd/118514881 Breitinger, Johann Jakob (40 pageviews)
# https://d-nb.info/gnd/118515055 Brentano, Clemens (57870 pageviews)
# https://d-nb.info/gnd/118515187 Breton, André (25358 pageviews)
# https://d-nb.info/gnd/118515470 Brinkmann, Rolf Dieter (12353 pageviews)
# https://d-nb.info/gnd/118674196 Britting, Georg (6467 pageviews)
# https://d-nb.info/gnd/118515551 Broch, Hermann (18734 pageviews)
# https://d-nb.info/gnd/118515586 Brockes, Barthold Heinrich (7470 pageviews)
# https://d-nb.info/gnd/118515691 Bronnen, Arnolt (13032 pageviews)
# https://d-nb.info/gnd/136148654 Bronsky, Alina (35817 pageviews)
# https://d-nb.info/gnd/118638017 Brontë, Emily (111105 pageviews)
# https://d-nb.info/gnd/129239321 Brooks, Kevin (4007 pageviews)
# https://d-nb.info/gnd/118515810 Bruckner, Karl (1881 pageviews)
# https://d-nb.info/gnd/119491028 Brussig, Thomas (16940 pageviews)
# https://d-nb.info/gnd/118516388 Bruyn, Günter de (12448 pageviews)
# https://d-nb.info/gnd/118514210 Bräker, Ulrich (4183 pageviews)
# https://d-nb.info/gnd/116385782 Bräunig, Werner (3131 pageviews)
# https://d-nb.info/gnd/11851587X Brückner, Christine (16380 pageviews)
# https://d-nb.info/gnd/118517376 Bulgakov, Michail (Seite nicht gefunden)
# https://d-nb.info/gnd/118517600 Burger, Hermann (7470 pageviews)
# https://d-nb.info/gnd/11811848X Burgess, Melvin (723 pageviews)
# https://d-nb.info/gnd/118517880 Busch, Wilhelm (138455 pageviews)
# https://d-nb.info/gnd/119022354 Busta, Christine (3972 pageviews)
# https://d-nb.info/gnd/119237873 Butler, Judith (141501 pageviews)
# https://d-nb.info/gnd/12405692X Bánk, Zsuzsa (12162 pageviews)
# https://d-nb.info/gnd/123991226 Bärfuss, Lukas (29602 pageviews)
# https://d-nb.info/gnd/118878484 Böhlau, Helene (2229 pageviews)
# https://d-nb.info/gnd/118512676 Böll, Heinrich (155632 pageviews)
# https://d-nb.info/gnd/118512749 Börne, Ludwig (21897 pageviews)
# https://d-nb.info/gnd/118516906 Büchner, Georg (194957 pageviews)
# https://d-nb.info/gnd/118517104 Bürger, Gottfried August (18118 pageviews)
# https://d-nb.info/gnd/118200283 Büscher, Wolfgang (2217 pageviews)
# https://d-nb.info/gnd/118518399 Calderón de la Barca, Pedro (16777 pageviews)
# https://d-nb.info/gnd/118518542 Calvino, Italo (36378 pageviews)
# https://d-nb.info/gnd/138119813 Camenisch, Arno (5165 pageviews)
# https://d-nb.info/gnd/118518658 Campe, Joachim Heinrich (12796 pageviews)
# https://d-nb.info/gnd/118518739 Camus, Albert (168946 pageviews)
# https://d-nb.info/gnd/118518801 Canetti, Elias (52929 pageviews)
# https://d-nb.info/gnd/119074087 Canetti, Veza (6711 pageviews)
# https://d-nb.info/gnd/118181505 Capus, Alex (38867 pageviews)
# https://d-nb.info/gnd/118519182 Carossa, Hans (16098 pageviews)
# https://d-nb.info/gnd/11851928X Carroll, Lewis (71920 pageviews)
# https://d-nb.info/gnd/118519522 Cassirer, Ernst (24394 pageviews)
# https://d-nb.info/gnd/118519859 Celan, Paul (93287 pageviews)
# https://d-nb.info/gnd/11851993X Cervantes Saavedra, Miguel de (Seite nicht gefunden)
# https://d-nb.info/gnd/118520040 Chamisso, Adelbert von (38558 pageviews)
# https://d-nb.info/gnd/118520555 Christ, Lena (20309 pageviews)
# https://d-nb.info/gnd/119549263 Christen, Ada (1607 pageviews)
# https://d-nb.info/gnd/118520547 Chrétien de Troyes (10656 pageviews)
# https://d-nb.info/gnd/11852108X Claudius, Eduard (2134 pageviews)
# https://d-nb.info/gnd/118521098 Claudius, Matthias (38932 pageviews)
# https://d-nb.info/gnd/118676369 Claus, Carlfriedrich (3757 pageviews)
# https://d-nb.info/gnd/118521349 Cocteau, Jean (91033 pageviews)
# https://d-nb.info/gnd/118895117 Coetzee, J. M. (20379 pageviews)
# https://d-nb.info/gnd/124045324 Colfer, Eoin (9209 pageviews)
# https://d-nb.info/gnd/130042161 Collins, Suzanne (51094 pageviews)
# https://d-nb.info/gnd/118669788 Collodi, Carlo (18610 pageviews)
# https://d-nb.info/gnd/118521861 Conrad, Joseph (52768 pageviews)
# https://d-nb.info/gnd/118669923 Conradi, Hermann (1295 pageviews)
# https://d-nb.info/gnd/118676865 Cooper, James Fenimore (33511 pageviews)
# https://d-nb.info/gnd/132957078 Cotten, Ann (7177 pageviews)
# https://d-nb.info/gnd/129728934 Cottrell Boyce, Frank (1204 pageviews)
# https://d-nb.info/gnd/123728134 Creech, Sharon (211 pageviews)
# https://d-nb.info/gnd/118523058 Curtius, Ernst Robert (6721 pageviews)
# https://d-nb.info/gnd/11852321X Dach, Simon (9570 pageviews)
# https://d-nb.info/gnd/118630962 Dahl, Roald (184221 pageviews)
# https://d-nb.info/gnd/118523392 Dahn, Felix (13347 pageviews)
# https://d-nb.info/gnd/121550656 Damm, Sigrid (6155 pageviews)
# https://d-nb.info/gnd/129890758 Danckwart, Gesine (895 pageviews)
# https://d-nb.info/gnd/129428906 Danz, Daniela (4426 pageviews)
# https://d-nb.info/gnd/12263621X Dath, Dietmar (23977 pageviews)
# https://d-nb.info/gnd/118678973 Dauthendey, Max (7603 pageviews)
# https://d-nb.info/gnd/119522713 De Cesco, Federica (Seite nicht gefunden)
# https://d-nb.info/gnd/118671251 Dedekind, Friedrich (494 pageviews)
# https://d-nb.info/gnd/118524275 Defoe, Daniel (44381 pageviews)
# https://d-nb.info/gnd/118679236 Dehmel, Richard (20772 pageviews)
# https://d-nb.info/gnd/118924389 Delius, Friedrich Christian (16512 pageviews)
# https://d-nb.info/gnd/121373940 Demirkan, Renan (100635 pageviews)
# https://d-nb.info/gnd/118619284 Der Stricker (3331 pageviews)
# https://d-nb.info/gnd/118567756 Der von Kürenberg (6531 pageviews)
# https://d-nb.info/gnd/118677888 Derrida, Jacques (42752 pageviews)
# https://d-nb.info/gnd/118525239 Dickens, Charles (164188 pageviews)
# https://d-nb.info/gnd/11867191X Dietmar von Aist (3083 pageviews)
# https://d-nb.info/gnd/118525727 Dilthey, Wilhelm (23950 pageviews)
# https://d-nb.info/gnd/120246910 Dische, Irene (14253 pageviews)
# https://d-nb.info/gnd/119151200 Djebar, Assia (4391 pageviews)
# https://d-nb.info/gnd/118526162 Doderer, Heimito von (33182 pageviews)
# https://d-nb.info/gnd/120869322 Doherty, Berlie (244 pageviews)
# https://d-nb.info/gnd/11852643X Dohm, Hedwig (182084 pageviews)
# https://d-nb.info/gnd/118526634 Domin, Hilde (38566 pageviews)
# https://d-nb.info/gnd/119123754 Dorfman, Ariel (2159 pageviews)
# https://d-nb.info/gnd/118526952 Dorst, Tankred (14829 pageviews)
# https://d-nb.info/gnd/118527053 Dostoevskij, Fëdor Michajlovič (Seite nicht gefunden)
# https://d-nb.info/gnd/131915975 Dowd, Siobhan (1335 pageviews)
# https://d-nb.info/gnd/11852710X Doyle, Arthur Conan (109239 pageviews)
# https://d-nb.info/gnd/118680625 Drach, Albert (2524 pageviews)
# https://d-nb.info/gnd/115834087 Draesner, Ulrike (12725 pageviews)
# https://d-nb.info/gnd/121527212 Drawert, Kurt (3035 pageviews)
# https://d-nb.info/gnd/11852741X Drewitz, Ingeborg (4696 pageviews)
# https://d-nb.info/gnd/118527533 Droste-Hülshoff, Annette von (166376 pageviews)
# https://d-nb.info/gnd/120560216 Druskowitz, Helene von (15621 pageviews)
# https://d-nb.info/gnd/118922335 Duden, Anne (1273 pageviews)
# https://d-nb.info/gnd/118528068 Dumas, Alexandre (5684 pageviews)
# https://d-nb.info/gnd/118528254 Duras, Marguerite (26058 pageviews)
# https://d-nb.info/gnd/128923865 Durzak, Manfred (871 pageviews)
# https://d-nb.info/gnd/115673776 Duve, Karen (25833 pageviews)
# https://d-nb.info/gnd/118526200 Döblin, Alfred (53346 pageviews)
# https://d-nb.info/gnd/121063984 Dückers, Tanja (4054 pageviews)
# https://d-nb.info/gnd/115883673 Düffel, John von (16948 pageviews)
# https://d-nb.info/gnd/118527908 Dürrenmatt, Friedrich (183613 pageviews)
# https://d-nb.info/gnd/118534556 Fouqué, Friedrich de La Motte- (Seite nicht gefunden)
# https://d-nb.info/gnd/108082652 George, Jean Craighead (579 pageviews)
# https://d-nb.info/gnd/115807454 Hage, Volker (2013 pageviews)
# https://d-nb.info/gnd/118565060 Konrad der Pfaffe (Seite nicht gefunden)
# https://d-nb.info/gnd/11856868X La Fontaine, Jean de (23178 pageviews)
# https://d-nb.info/gnd/13345052X Marsch, Edgar (142 pageviews)
# https://d-nb.info/gnd/118579207 Maupassant, Guy de (59037 pageviews)
# https://d-nb.info/gnd/129396532 Nadj Abonji, Melinda (4304 pageviews)
# https://d-nb.info/gnd/118604902 Saint-Exupéry, Antoine de (132705 pageviews)
# https://d-nb.info/gnd/118631551 Werner der Gärtner (Seite nicht gefunden)
# https://d-nb.info/gnd/119491834 Winter, Léon de (Seite nicht gefunden)
# https://d-nb.info/gnd/119040581 Zanger, Jan F. de (Seite nicht gefunden)
# https://d-nb.info/gnd/119406586 Özdamar, Emine Sevgi (17386 pageviews)
# https://d-nb.info/gnd/118638289 Čechov, Anton Pavlovič (Seite nicht gefunden)
# https://d-nb.info/gnd/118735969 Ōe, Kenzaburō (11658 pageviews)

# %%
wiki = wiki.sort_values(by = 'GND_Autor')

# %%
wiki.to_csv("/content/drive/MyDrive/2024.Kanonizität/resources/04_wiki.csv")

# %% [markdown]
# ### Import and Merge

# %%
wiki = pd.read_csv("/content/drive/MyDrive/2024.Kanonizität/resources/04_wiki.csv", index_col = [0])

# %%
for this_index in all_authors.index:
  if this_index in wiki.index:
    all_authors.at[this_index, 'Wiki_Autor'] = wiki.at[this_index, 'title']
    all_authors.at[this_index, 'Wiki_Summe'] = wiki.at[this_index, 'pageviews_365d']

# %%
all_authors.loc[test_links][[
    'Leselisten_Autor', 'Wiki_Autor',
    'Wiki_Summe'
]]
# Out:
#                                       Leselisten_Autor            Wiki_Autor  \
# https://d-nb.info/gnd/118500856              Aischylos                   NaN
# https://d-nb.info/gnd/118501232        Aichinger, Ilse        Ilse Aichinger
# https://d-nb.info/gnd/118505602     Bachmann, Ingeborg     Ingeborg Bachmann
# https://d-nb.info/gnd/118516906         Büchner, Georg         Georg Büchner
# https://d-nb.info/gnd/118519859            Celan, Paul            Paul Celan
# https://d-nb.info/gnd/118527908  Dürrenmatt, Friedrich  Friedrich Dürrenmatt
#
#                                  Wiki_Summe
# https://d-nb.info/gnd/118500856         0.0
# https://d-nb.info/gnd/118501232     31821.0
# https://d-nb.info/gnd/118505602    394707.0
# https://d-nb.info/gnd/118516906    194957.0
# https://d-nb.info/gnd/118519859     93287.0
# https://d-nb.info/gnd/118527908    183613.0

# %% [markdown]
# # BDSL

# %% [markdown]
# ### Scrape

# %%
# !pip3 install google_colab_selenium
import google_colab_selenium as gs
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

# %%
driver = gs.Chrome()
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="304708ee-e04d-471d-a336-80d082a82504-circle"></div>
#                 <div class="spinner-text" id="304708ee-e04d-471d-a336-80d082a82504-text">Updating and upgrading APT</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="209d413a-4422-48a9-afef-28d8e2685024-circle"></div>
#                 <div class="spinner-text" id="209d413a-4422-48a9-afef-28d8e2685024-text">Downloading Google Chrome</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="73036ab0-e3bb-4384-8fca-fa49da3fa666-circle"></div>
#                 <div class="spinner-text" id="73036ab0-e3bb-4384-8fca-fa49da3fa666-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>

# %%
# log in via SUB Göttingen
driver.get("http://han.sub.uni-goettingen.de/han/BDSL")

username = driver.find_element(By.ID, "plainuser")
username.send_keys("000721344262")

password = driver.find_element(By.ID, "password")
password.send_keys("karen1na")

password.send_keys(Keys.RETURN)

# %%
bdsl = pd.DataFrame()

for gnd_link in tqdm(all_authors.sort_values(by='GND_Autor').index):
  author = all_authors.loc[gnd_link, 'GND_Autor']
  if pd.isna(author):
    author = '(nan) XXX'

  # go to search
  driver.find_element(By.LINK_TEXT, "Suche").click()

  # change dropdown to 'Behandelte Person'
  dropdown_menu = driver.find_element(By.NAME, "DD1")
  select = Select(dropdown_menu)
  select.select_by_value("4")

  # enter author name
  input_field = driver.find_element(By.NAME, "SF1")
  input_field.send_keys(author)

  # search for author
  input_field.send_keys(Keys.RETURN)

  # get number of results
  page_source = driver.page_source
  hits_str = re.findall("\d* Titel gefunden", page_source)

  if len(hits_str) == 0 or hits_str[0].startswith(' Titel'):
    hits_int = 0
  else:
    hits_int = int(hits_str[0].split(" ")[0])

  print(f"{gnd_link} {author} ({hits_int} Treffer)")
  bdsl.at[gnd_link, 'GND_Autor'] = author
  bdsl.at[gnd_link, 'BDSL_Summe'] = hits_int

bdsl['BDSL_Summe'] = bdsl['BDSL_Summe'].fillna(0)
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# https://d-nb.info/gnd/118646680 Achebe, Chinua (0 Treffer)
# https://d-nb.info/gnd/119369125 Achleitner, Friedrich (31 Treffer)
# https://d-nb.info/gnd/118500422 Achternbusch, Herbert (75 Treffer)
# https://d-nb.info/gnd/138053669 Ade, Maren (0 Treffer)
# https://d-nb.info/gnd/118500775 Adorno, Theodor W. (1282 Treffer)
# https://d-nb.info/gnd/118500856 Aeschylus (0 Treffer)
# https://d-nb.info/gnd/118647180 Aesopus (0 Treffer)
# https://d-nb.info/gnd/119293439 Agamben, Giorgio (0 Treffer)
# https://d-nb.info/gnd/118501232 Aichinger, Ilse (537 Treffer)
# https://d-nb.info/gnd/118501259 Ajtmatov, Čingiz (0 Treffer)
# https://d-nb.info/gnd/118501380 Albee, Edward (0 Treffer)
# https://d-nb.info/gnd/119604108 Alciato, Andreas (0 Treffer)
# https://d-nb.info/gnd/1256774294 Alighieri, Dante (0 Treffer)
# https://d-nb.info/gnd/118869159 Allende, Isabel (0 Treffer)
# https://d-nb.info/gnd/123526183 Almond, David (0 Treffer)
# https://d-nb.info/gnd/118502255 Altenberg, Peter (154 Treffer)
# https://d-nb.info/gnd/115674861 Altenburg, Matthias (7 Treffer)
# https://d-nb.info/gnd/118937197 Amery, Carl (42 Treffer)
# https://d-nb.info/gnd/118502786 Andersch, Alfred (384 Treffer)
# https://d-nb.info/gnd/118502794 Andersen, Hans Christian (0 Treffer)
# https://d-nb.info/gnd/119111365 Anderson, Sascha (28 Treffer)
# https://d-nb.info/gnd/118502921 Andreas-Salomé, Lou (349 Treffer)
# https://d-nb.info/gnd/118502956 Andres, Stefan (282 Treffer)
# https://d-nb.info/gnd/118503111 Angelus Silesius (79 Treffer)
# https://d-nb.info/gnd/120315106 Ani, Friedrich (23 Treffer)
# https://d-nb.info/gnd/118503251 Anouilh, Jean (0 Treffer)
# https://d-nb.info/gnd/11850357X Anzengruber, Ludwig (37 Treffer)
# https://d-nb.info/gnd/118829637 Apitz, Bruno (41 Treffer)
# https://d-nb.info/gnd/11850374X Apuleius Madaurensis (0 Treffer)
# https://d-nb.info/gnd/1188043420 Arb, Nando von (0 Treffer)
# https://d-nb.info/gnd/11850391X Arendt, Hannah (697 Treffer)
# https://d-nb.info/gnd/118650130 Aristoteles (0 Treffer)
# https://d-nb.info/gnd/118184555 Arjouni, Jakob (45 Treffer)
# https://d-nb.info/gnd/118504177 Arnim, Achim von (670 Treffer)
# https://d-nb.info/gnd/118504185 Arnim, Bettina von (642 Treffer)
# https://d-nb.info/gnd/118504398 Arp, Hans (95 Treffer)
# https://d-nb.info/gnd/11850441X Arrabal, Fernando (0 Treffer)
# https://d-nb.info/gnd/118504495 Artaud, Antonin (0 Treffer)
# https://d-nb.info/gnd/118504533 Artmann, H. C. (242 Treffer)
# https://d-nb.info/gnd/120430991 Asscher-Pinkhof, Clara (0 Treffer)
# https://d-nb.info/gnd/11805077X Assmann, Jan (0 Treffer)
# https://d-nb.info/gnd/118650769 Aston, Louise (33 Treffer)
# https://d-nb.info/gnd/118646168 Atwood, Margaret (0 Treffer)
# https://d-nb.info/gnd/11865103X Auerbach, Berthold (148 Treffer)
# https://d-nb.info/gnd/118505025 Auerbach, Erich (197 Treffer)
# https://d-nb.info/gnd/115699635 Augstburger, Urs (0 Treffer)
# https://d-nb.info/gnd/118829211 Ausländer, Rose (389 Treffer)
# https://d-nb.info/gnd/118505173 Austen, Jane (0 Treffer)
# https://d-nb.info/gnd/11910251X Auster, Paul (0 Treffer)
# https://d-nb.info/gnd/119025698 Ava Frau (19 Treffer)
# https://d-nb.info/gnd/120841916 Babendererde, Antje (5 Treffer)
# https://d-nb.info/gnd/12493272X Bach, Tamara (21 Treffer)
# https://d-nb.info/gnd/118505602 Bachmann, Ingeborg (2218 Treffer)
# https://d-nb.info/gnd/118505653 Bachtin, Michail Michajlovič (0 Treffer)
# https://d-nb.info/gnd/118505955 Bahr, Hermann (301 Treffer)
# https://d-nb.info/gnd/118506234 Ball, Hugo (333 Treffer)
# https://d-nb.info/gnd/118506358 Balzac, Honoré de (0 Treffer)
# https://d-nb.info/gnd/115743030 Baricco, Alessandro (0 Treffer)
# https://d-nb.info/gnd/118506617 Barlach, Ernst (189 Treffer)
# https://d-nb.info/gnd/1095775561 Barthel, Kurt (0 Treffer)
# https://d-nb.info/gnd/118506862 Barthes, Roland (0 Treffer)
# https://d-nb.info/gnd/118507184 Baudelaire, Charles (0 Treffer)
# https://d-nb.info/gnd/124462316 Bauer, Marion Dane (0 Treffer)
# https://d-nb.info/gnd/133528650 Bauer, Michael Gerard (0 Treffer)
# https://d-nb.info/gnd/118507397 Bauer, Wolfgang (107 Treffer)
# https://d-nb.info/gnd/128366974 Bauersima, Igor (7 Treffer)
# https://d-nb.info/gnd/1016386486 Baum, Antonia (5 Treffer)
# https://d-nb.info/gnd/118653830 Baum, Vicki (132 Treffer)
# https://d-nb.info/gnd/118507605 Baumgarten, Alexander Gottlieb (94 Treffer)
# https://d-nb.info/gnd/118507753 Bayer, Konrad (73 Treffer)
# https://d-nb.info/gnd/118507877 Beauvoir, Simone de (0 Treffer)
# https://d-nb.info/gnd/118507931 Becher, Johannes Robert (253 Treffer)
# https://d-nb.info/gnd/118654292 Bechstein, Ludwig (51 Treffer)
# https://d-nb.info/gnd/118829742 Becker, Jurek (300 Treffer)
# https://d-nb.info/gnd/118508091 Becker, Jürgen (123 Treffer)
# https://d-nb.info/gnd/118508172 Beckett, Samuel (0 Treffer)
# https://d-nb.info/gnd/118508253 Beer, Johann (156 Treffer)
# https://d-nb.info/gnd/118654756 Beer-Hofmann, Richard (145 Treffer)
# https://d-nb.info/gnd/115371915 Begley, Louis (0 Treffer)
# https://d-nb.info/gnd/120555573 Bekker, Alfred (1 Treffer)
# https://d-nb.info/gnd/118509039 Benjamin, Walter (3796 Treffer)
# https://d-nb.info/gnd/118509047 Benn, Gottfried (1335 Treffer)
# https://d-nb.info/gnd/124742823 Berg, Sibylle (82 Treffer)
# https://d-nb.info/gnd/11850939X Bergengruen, Werner (101 Treffer)
# https://d-nb.info/gnd/118509578 Bergson, Henri (0 Treffer)
# https://d-nb.info/gnd/133565777 Berkenheger, Susanne (6 Treffer)
# https://d-nb.info/gnd/119150026 Berkéwicz, Ulla (32 Treffer)
# https://d-nb.info/gnd/118509861 Bernhard, Thomas (2161 Treffer)
# https://d-nb.info/gnd/129738387 Bertram, Rüdiger (0 Treffer)
# https://d-nb.info/gnd/124932479 Bessing, Joachim (27 Treffer)
# https://d-nb.info/gnd/11548048X Beyer, Marcel (282 Treffer)
# https://d-nb.info/gnd/118510649 Bichsel, Peter (169 Treffer)
# https://d-nb.info/gnd/119621290 Bidermann, Jakob (48 Treffer)
# https://d-nb.info/gnd/118510754 Bienek, Horst (189 Treffer)
# https://d-nb.info/gnd/118510789 Biermann, Wolf (175 Treffer)
# https://d-nb.info/gnd/12126582X Biller, Maxim (99 Treffer)
# https://d-nb.info/gnd/118511270 Birken, Sigmund von (169 Treffer)
# https://d-nb.info/gnd/136059201 Bjerg, Bov (4 Treffer)
# https://d-nb.info/gnd/119025701 Blankenburg, Christian Friedrich von (22 Treffer)
# https://d-nb.info/gnd/111492167X Bleidiek, Thomas (0 Treffer)
# https://d-nb.info/gnd/118511742 Bloch, Ernst (418 Treffer)
# https://d-nb.info/gnd/118511963 Blumauer, Alois (28 Treffer)
# https://d-nb.info/gnd/118664123 Blumenberg, Hans (227 Treffer)
# https://d-nb.info/gnd/118512161 Bobrowski, Johannes (434 Treffer)
# https://d-nb.info/gnd/11851217X Boccaccio, Giovanni (0 Treffer)
# https://d-nb.info/gnd/118512315 Bodmer, Johann Jakob (138 Treffer)
# https://d-nb.info/gnd/12363816X Bodrozić, Marica (73 Treffer)
# https://d-nb.info/gnd/119501252 Boie, Kirsten (36 Treffer)
# https://d-nb.info/gnd/118661175 Boldt, Paul (14 Treffer)
# https://d-nb.info/gnd/118513435 Borchardt, Rudolf (325 Treffer)
# https://d-nb.info/gnd/118513451 Borchert, Wolfgang (300 Treffer)
# https://d-nb.info/gnd/118513532 Borges, Jorge Luis (0 Treffer)
# https://d-nb.info/gnd/11851363X Born, Nicolas (118 Treffer)
# https://d-nb.info/gnd/118513931 Bote, Hermann (104 Treffer)
# https://d-nb.info/gnd/118810758 Bourdieu, Pierre (0 Treffer)
# https://d-nb.info/gnd/119520478 Boyle, T. Coraghessan (0 Treffer)
# https://d-nb.info/gnd/133252922 Boyne, John (0 Treffer)
# https://d-nb.info/gnd/118659723 Bradbury, Ray (0 Treffer)
# https://d-nb.info/gnd/119422999 Brambach, Rainer (16 Treffer)
# https://d-nb.info/gnd/118514512 Brasch, Thomas (96 Treffer)
# https://d-nb.info/gnd/118514644 Braun, Volker (497 Treffer)
# https://d-nb.info/gnd/118514768 Brecht, Bertolt (5278 Treffer)
# https://d-nb.info/gnd/118514776 Bredel, Willi (33 Treffer)
# https://d-nb.info/gnd/118514881 Breitinger, Johann Jakob (58 Treffer)
# https://d-nb.info/gnd/118515055 Brentano, Clemens (789 Treffer)
# https://d-nb.info/gnd/118515187 Breton, André (0 Treffer)
# https://d-nb.info/gnd/118515470 Brinkmann, Rolf Dieter (369 Treffer)
# https://d-nb.info/gnd/118674196 Britting, Georg (70 Treffer)
# https://d-nb.info/gnd/118515551 Broch, Hermann (1083 Treffer)
# https://d-nb.info/gnd/118515586 Brockes, Barthold Heinrich (135 Treffer)
# https://d-nb.info/gnd/118515691 Bronnen, Arnolt (92 Treffer)
# https://d-nb.info/gnd/136148654 Bronsky, Alina (25 Treffer)
# https://d-nb.info/gnd/118638017 Brontë, Emily (0 Treffer)
# https://d-nb.info/gnd/129239321 Brooks, Kevin (0 Treffer)
# https://d-nb.info/gnd/118515810 Bruckner, Karl (5 Treffer)
# https://d-nb.info/gnd/119491028 Brussig, Thomas (145 Treffer)
# https://d-nb.info/gnd/118516388 Bruyn, Günter de (267 Treffer)
# https://d-nb.info/gnd/118514210 Bräker, Ulrich (76 Treffer)
# https://d-nb.info/gnd/116385782 Bräunig, Werner (26 Treffer)
# https://d-nb.info/gnd/11851587X Brückner, Christine (74 Treffer)
# https://d-nb.info/gnd/118517376 Bulgakov, Michail (0 Treffer)
# https://d-nb.info/gnd/118517600 Burger, Hermann (182 Treffer)
# https://d-nb.info/gnd/11811848X Burgess, Melvin (0 Treffer)
# https://d-nb.info/gnd/118517880 Busch, Wilhelm (283 Treffer)
# https://d-nb.info/gnd/119022354 Busta, Christine (46 Treffer)
# https://d-nb.info/gnd/119237873 Butler, Judith (0 Treffer)
# https://d-nb.info/gnd/12405692X Bánk, Zsuzsa (34 Treffer)
# https://d-nb.info/gnd/123991226 Bärfuss, Lukas (101 Treffer)
# https://d-nb.info/gnd/118878484 Böhlau, Helene (23 Treffer)
# https://d-nb.info/gnd/118512676 Böll, Heinrich (1095 Treffer)
# https://d-nb.info/gnd/118512749 Börne, Ludwig (234 Treffer)
# https://d-nb.info/gnd/118516906 Büchner, Georg (1775 Treffer)
# https://d-nb.info/gnd/118517104 Bürger, Gottfried August (163 Treffer)
# https://d-nb.info/gnd/118200283 Büscher, Wolfgang (23 Treffer)
# https://d-nb.info/gnd/118518399 Calderón de la Barca, Pedro (0 Treffer)
# https://d-nb.info/gnd/118518542 Calvino, Italo (0 Treffer)
# https://d-nb.info/gnd/138119813 Camenisch, Arno (14 Treffer)
# https://d-nb.info/gnd/118518658 Campe, Joachim Heinrich (124 Treffer)
# https://d-nb.info/gnd/118518739 Camus, Albert (0 Treffer)
# https://d-nb.info/gnd/118518801 Canetti, Elias (1377 Treffer)
# https://d-nb.info/gnd/119074087 Canetti, Veza (114 Treffer)
# https://d-nb.info/gnd/118181505 Capus, Alex (27 Treffer)
# https://d-nb.info/gnd/118519182 Carossa, Hans (74 Treffer)
# https://d-nb.info/gnd/11851928X Carroll, Lewis (0 Treffer)
# https://d-nb.info/gnd/118519522 Cassirer, Ernst (188 Treffer)
# https://d-nb.info/gnd/118519859 Celan, Paul (2951 Treffer)
# https://d-nb.info/gnd/11851993X Cervantes Saavedra, Miguel de (0 Treffer)
# https://d-nb.info/gnd/118520040 Chamisso, Adelbert von (356 Treffer)
# https://d-nb.info/gnd/118520555 Christ, Lena (32 Treffer)
# https://d-nb.info/gnd/119549263 Christen, Ada (8 Treffer)
# https://d-nb.info/gnd/118520547 Chrétien de Troyes (0 Treffer)
# https://d-nb.info/gnd/11852108X Claudius, Eduard (22 Treffer)
# https://d-nb.info/gnd/118521098 Claudius, Matthias (347 Treffer)
# https://d-nb.info/gnd/118676369 Claus, Carlfriedrich (45 Treffer)
# https://d-nb.info/gnd/118521349 Cocteau, Jean (0 Treffer)
# https://d-nb.info/gnd/118895117 Coetzee, J. M. (0 Treffer)
# https://d-nb.info/gnd/124045324 Colfer, Eoin (0 Treffer)
# https://d-nb.info/gnd/130042161 Collins, Suzanne (0 Treffer)
# https://d-nb.info/gnd/118669788 Collodi, Carlo (0 Treffer)
# https://d-nb.info/gnd/118521861 Conrad, Joseph (5 Treffer)
# https://d-nb.info/gnd/118669923 Conradi, Hermann (8 Treffer)
# https://d-nb.info/gnd/118676865 Cooper, James Fenimore (0 Treffer)
# https://d-nb.info/gnd/132957078 Cotten, Ann (60 Treffer)
# https://d-nb.info/gnd/129728934 Cottrell Boyce, Frank (0 Treffer)
# https://d-nb.info/gnd/123728134 Creech, Sharon (0 Treffer)
# https://d-nb.info/gnd/118523058 Curtius, Ernst Robert (142 Treffer)
# https://d-nb.info/gnd/11852321X Dach, Simon (73 Treffer)
# https://d-nb.info/gnd/118630962 Dahl, Roald (0 Treffer)
# https://d-nb.info/gnd/118523392 Dahn, Felix (29 Treffer)
# https://d-nb.info/gnd/121550656 Damm, Sigrid (106 Treffer)
# https://d-nb.info/gnd/129890758 Danckwart, Gesine (6 Treffer)
# https://d-nb.info/gnd/129428906 Danz, Daniela (22 Treffer)
# https://d-nb.info/gnd/12263621X Dath, Dietmar (95 Treffer)
# https://d-nb.info/gnd/118678973 Dauthendey, Max (64 Treffer)
# https://d-nb.info/gnd/119522713 De Cesco, Federica (0 Treffer)
# https://d-nb.info/gnd/118671251 Dedekind, Friedrich (10 Treffer)
# https://d-nb.info/gnd/118524275 Defoe, Daniel (0 Treffer)
# https://d-nb.info/gnd/118679236 Dehmel, Richard (85 Treffer)
# https://d-nb.info/gnd/118924389 Delius, Friedrich Christian (189 Treffer)
# https://d-nb.info/gnd/121373940 Demirkan, Renan (11 Treffer)
# https://d-nb.info/gnd/118619284 Der Stricker (215 Treffer)
# https://d-nb.info/gnd/118567756 Der von Kürenberg (31 Treffer)
# https://d-nb.info/gnd/118677888 Derrida, Jacques (0 Treffer)
# https://d-nb.info/gnd/118525239 Dickens, Charles (0 Treffer)
# https://d-nb.info/gnd/11867191X Dietmar von Aist (17 Treffer)
# https://d-nb.info/gnd/118525727 Dilthey, Wilhelm (127 Treffer)
# https://d-nb.info/gnd/120246910 Dische, Irene (0 Treffer)
# https://d-nb.info/gnd/119151200 Djebar, Assia (0 Treffer)
# https://d-nb.info/gnd/118526162 Doderer, Heimito von (590 Treffer)
# https://d-nb.info/gnd/120869322 Doherty, Berlie (0 Treffer)
# https://d-nb.info/gnd/11852643X Dohm, Hedwig (103 Treffer)
# https://d-nb.info/gnd/118526634 Domin, Hilde (223 Treffer)
# https://d-nb.info/gnd/119123754 Dorfman, Ariel (0 Treffer)
# https://d-nb.info/gnd/118526952 Dorst, Tankred (211 Treffer)
# https://d-nb.info/gnd/118527053 Dostoevskij, Fëdor Michajlovič (0 Treffer)
# https://d-nb.info/gnd/131915975 Dowd, Siobhan (0 Treffer)
# https://d-nb.info/gnd/11852710X Doyle, Arthur Conan (0 Treffer)
# https://d-nb.info/gnd/118680625 Drach, Albert (124 Treffer)
# https://d-nb.info/gnd/115834087 Draesner, Ulrike (210 Treffer)
# https://d-nb.info/gnd/121527212 Drawert, Kurt (112 Treffer)
# https://d-nb.info/gnd/11852741X Drewitz, Ingeborg (105 Treffer)
# https://d-nb.info/gnd/118527533 Droste-Hülshoff, Annette von (901 Treffer)
# https://d-nb.info/gnd/120560216 Druskowitz, Helene von (8 Treffer)
# https://d-nb.info/gnd/118922335 Duden, Anne (88 Treffer)
# https://d-nb.info/gnd/118528068 Dumas, Alexandre (0 Treffer)
# https://d-nb.info/gnd/118528254 Duras, Marguerite (0 Treffer)
# https://d-nb.info/gnd/128923865 Durzak, Manfred (191 Treffer)
# https://d-nb.info/gnd/115673776 Duve, Karen (65 Treffer)
# https://d-nb.info/gnd/118526200 Döblin, Alfred (1463 Treffer)
# https://d-nb.info/gnd/121063984 Dückers, Tanja (70 Treffer)
# https://d-nb.info/gnd/115883673 Düffel, John von (95 Treffer)
# https://d-nb.info/gnd/118527908 Dürrenmatt, Friedrich (1075 Treffer)
# https://d-nb.info/gnd/118534556 Fouqué, Friedrich de La Motte- (218 Treffer)
# https://d-nb.info/gnd/108082652 George, Jean Craighead (0 Treffer)
# https://d-nb.info/gnd/115807454 Hage, Volker (110 Treffer)
# https://d-nb.info/gnd/118565060 Konrad der Pfaffe (146 Treffer)
# https://d-nb.info/gnd/11856868X La Fontaine, Jean de (0 Treffer)
# https://d-nb.info/gnd/13345052X Marsch, Edgar (0 Treffer)
# https://d-nb.info/gnd/118579207 Maupassant, Guy de (0 Treffer)
# https://d-nb.info/gnd/129396532 Nadj Abonji, Melinda (61 Treffer)
# https://d-nb.info/gnd/118604902 Saint-Exupéry, Antoine de (0 Treffer)
# https://d-nb.info/gnd/118631551 Werner der Gärtner (72 Treffer)
# https://d-nb.info/gnd/119491834 Winter, Léon de (2 Treffer)
# https://d-nb.info/gnd/119040581 Zanger, Jan F. de (0 Treffer)
# https://d-nb.info/gnd/119406586 Özdamar, Emine Sevgi (351 Treffer)
# https://d-nb.info/gnd/118638289 Čechov, Anton Pavlovič (0 Treffer)
# https://d-nb.info/gnd/118735969 Ōe, Kenzaburō (0 Treffer)

# %%
bdsl.to_csv("/content/drive/MyDrive/2024.Kanonizität/resources/03_bdsl.csv")

# %% [markdown]
# ### Import and Merge

# %%
bdsl = pd.read_csv("/content/drive/MyDrive/2024.Kanonizität/resources/03_bdsl.csv", index_col = [0])

# %%
for this_index in all_authors.index:
  if this_index in bdsl.index:
    all_authors.at[this_index, 'BDSL_Summe'] = bdsl.at[this_index, 'BDSL_Summe']

# %%
all_authors.loc[test_links][[
    'Leselisten_Autor', 'Schule_Autor',
    'BDSL_Summe'
]]
# Out:
#                                       Leselisten_Autor Schule_Autor  \
# https://d-nb.info/gnd/118500856              Aischylos    Aischylos
# https://d-nb.info/gnd/118501232        Aichinger, Ilse    Aichinger
# https://d-nb.info/gnd/118505602     Bachmann, Ingeborg     Bachmann
# https://d-nb.info/gnd/118516906         Büchner, Georg      Büchner
# https://d-nb.info/gnd/118519859            Celan, Paul        Celan
# https://d-nb.info/gnd/118527908  Dürrenmatt, Friedrich   Dürrenmatt
#
#                                  BDSL_Summe
# https://d-nb.info/gnd/118500856         0.0
# https://d-nb.info/gnd/118501232       537.0
# https://d-nb.info/gnd/118505602      2218.0
# https://d-nb.info/gnd/118516906      1775.0
# https://d-nb.info/gnd/118519859      2951.0
# https://d-nb.info/gnd/118527908      1075.0

# %% [markdown]
# # Metrics

# %%
all_authors['Leselisten_Summe'] = all_authors[['Leselisten_'+x for x in leselisten]].sum(axis=1)
all_authors['Leselisten_Anteil'] = all_authors['Leselisten_Summe']/all_authors['Leselisten_Summe'].sum()
all_authors['Leselisten_Rang'] = all_authors['Leselisten_Summe'].rank(ascending=False)

# %%
all_authors['Schule_Summe'] = all_authors[['Schule_'+x for x in schule_titles['Bundesland'].unique()]].sum(axis=1)
all_authors['Schule_Anteil'] = all_authors['Schule_Summe']/all_authors['Schule_Summe'].sum()
all_authors['Schule_Rang'] = all_authors['Schule_Summe'].rank(ascending=False)

# %%
all_authors['BDSL_Anteil'] = all_authors['BDSL_Summe']/all_authors['BDSL_Summe'].sum()
all_authors['BDSL_Rang'] = all_authors['BDSL_Summe'].rank(ascending=False)

# %%
all_authors['Wiki_Anteil'] = all_authors['Wiki_Summe']/all_authors['Wiki_Summe'].sum()
all_authors['Wiki_Rang'] = all_authors['Wiki_Summe'].rank(ascending=False)

# %% [markdown]
# # Check

# %%
all_authors.head()
# Out:
#                                  Leselisten_Autor  Leselisten_Aachen2  \
# https://d-nb.info/gnd/1016386486              NaN                 0.0
# https://d-nb.info/gnd/108082652               NaN                 0.0
# https://d-nb.info/gnd/1095775561    Barthel, Kurt                 0.0
# https://d-nb.info/gnd/111492167X              NaN                 0.0
# https://d-nb.info/gnd/115371915               NaN                 0.0
#
#                                   Leselisten_Aachen1  Leselisten_Augsburg  \
# https://d-nb.info/gnd/1016386486                 0.0                  0.0
# https://d-nb.info/gnd/108082652                  0.0                  0.0
# https://d-nb.info/gnd/1095775561                 0.0                  0.0
# https://d-nb.info/gnd/111492167X                 0.0                  0.0
# https://d-nb.info/gnd/115371915                  0.0                  0.0
#
#                                   Leselisten_FU Berlin  Leselisten_Bochum  \
# https://d-nb.info/gnd/1016386486                   0.0                0.0
# https://d-nb.info/gnd/108082652                    0.0                0.0
# https://d-nb.info/gnd/1095775561                   0.0                0.0
# https://d-nb.info/gnd/111492167X                   0.0                0.0
# https://d-nb.info/gnd/115371915                    0.0                0.0
#
#                                   Leselisten_Braunschweig  \
# https://d-nb.info/gnd/1016386486                      0.0
# https://d-nb.info/gnd/108082652                       0.0
# https://d-nb.info/gnd/1095775561                      0.0
# https://d-nb.info/gnd/111492167X                      0.0
# https://d-nb.info/gnd/115371915                       0.0
#
#                                   Leselisten_Dortmund  Leselisten_Mannheim  \
# https://d-nb.info/gnd/1016386486                  0.0                  0.0
# https://d-nb.info/gnd/108082652                   0.0                  0.0
# https://d-nb.info/gnd/1095775561                  0.0                  0.0
# https://d-nb.info/gnd/111492167X                  0.0                  0.0
# https://d-nb.info/gnd/115371915                   0.0                  0.0
#
#                                   Leselisten_Eichstätt-Ingolstadt  ...  \
# https://d-nb.info/gnd/1016386486                              0.0  ...
# https://d-nb.info/gnd/108082652                               0.0  ...
# https://d-nb.info/gnd/1095775561                              0.0  ...
# https://d-nb.info/gnd/111492167X                              0.0  ...
# https://d-nb.info/gnd/115371915                               0.0  ...
#
#                                   Leselisten_Summe  Leselisten_Anteil  \
# https://d-nb.info/gnd/1016386486               0.0           0.000000
# https://d-nb.info/gnd/108082652                0.0           0.000000
# https://d-nb.info/gnd/1095775561               1.0           0.000716
# https://d-nb.info/gnd/111492167X               0.0           0.000000
# https://d-nb.info/gnd/115371915                0.0           0.000000
#
#                                   Leselisten_Rang  Schule_Summe  \
# https://d-nb.info/gnd/1016386486            214.0           1.0
# https://d-nb.info/gnd/108082652             214.0           2.0
# https://d-nb.info/gnd/1095775561            138.5           0.0
# https://d-nb.info/gnd/111492167X            214.0           1.0
# https://d-nb.info/gnd/115371915             214.0           2.0
#
#                                   Schule_Anteil  Schule_Rang  BDSL_Anteil  \
# https://d-nb.info/gnd/1016386486       0.002119        100.5     0.000103
# https://d-nb.info/gnd/108082652        0.004237         56.0     0.000000
# https://d-nb.info/gnd/1095775561       0.000000        188.0     0.000000
# https://d-nb.info/gnd/111492167X       0.002119        100.5     0.000000
# https://d-nb.info/gnd/115371915        0.004237         56.0     0.000000
#
#                                   BDSL_Rang  Wiki_Anteil  Wiki_Rang
# https://d-nb.info/gnd/1016386486      156.5     0.001322      126.0
# https://d-nb.info/gnd/108082652       204.5     0.000065      214.0
# https://d-nb.info/gnd/1095775561      204.5     0.000626      163.0
# https://d-nb.info/gnd/111492167X      204.5     0.000000      236.0
# https://d-nb.info/gnd/115371915       204.5     0.000877      141.0
#
# [5 rows x 73 columns]

# %%
all_authors.loc[test_links][[
    'GND_Autor',
    'Leselisten_Rang', 'Schule_Rang', 'BDSL_Rang', 'Wiki_Rang'
]]
# Out:
#                                              GND_Autor  Leselisten_Rang  \
# https://d-nb.info/gnd/118500856              Aeschylus             29.0
# https://d-nb.info/gnd/118501232        Aichinger, Ilse             15.0
# https://d-nb.info/gnd/118505602     Bachmann, Ingeborg              3.0
# https://d-nb.info/gnd/118516906         Büchner, Georg              2.0
# https://d-nb.info/gnd/118519859            Celan, Paul              6.0
# https://d-nb.info/gnd/118527908  Dürrenmatt, Friedrich              7.0
#
#                                  Schule_Rang  BDSL_Rang  Wiki_Rang
# https://d-nb.info/gnd/118500856        100.5      204.5      236.0
# https://d-nb.info/gnd/118501232        100.5       20.0       67.0
# https://d-nb.info/gnd/118505602          5.0        4.0        1.0
# https://d-nb.info/gnd/118516906          3.0        6.0        8.0
# https://d-nb.info/gnd/118519859         19.0        3.0       32.0
# https://d-nb.info/gnd/118527908          2.0       13.0       11.0

# %% [markdown]
# # Ergebnisse

# %%
all_authors.sort_values(by='Leselisten_Rang').head(20)[[
    'GND_Autor',
    'Leselisten_Rang', 'Schule_Rang', 'BDSL_Rang', 'Wiki_Rang'
]]
# Out:
#                                                     GND_Autor  \
# https://d-nb.info/gnd/118514768               Brecht, Bertolt
# https://d-nb.info/gnd/118516906                Büchner, Georg
# https://d-nb.info/gnd/118505602            Bachmann, Ingeborg
# https://d-nb.info/gnd/118509047               Benn, Gottfried
# https://d-nb.info/gnd/118509861              Bernhard, Thomas
# https://d-nb.info/gnd/118519859                   Celan, Paul
# https://d-nb.info/gnd/118527908         Dürrenmatt, Friedrich
# https://d-nb.info/gnd/118527533  Droste-Hülshoff, Annette von
# https://d-nb.info/gnd/118526200                Döblin, Alfred
# https://d-nb.info/gnd/118512676                Böll, Heinrich
# https://d-nb.info/gnd/118515055             Brentano, Clemens
# https://d-nb.info/gnd/118518801                Canetti, Elias
# https://d-nb.info/gnd/118513451            Borchert, Wolfgang
# https://d-nb.info/gnd/118509039              Benjamin, Walter
# https://d-nb.info/gnd/118501232               Aichinger, Ilse
# https://d-nb.info/gnd/118515470        Brinkmann, Rolf Dieter
# https://d-nb.info/gnd/118515586    Brockes, Barthold Heinrich
# https://d-nb.info/gnd/118504177              Arnim, Achim von
# https://d-nb.info/gnd/118504185            Arnim, Bettina von
# https://d-nb.info/gnd/118520040        Chamisso, Adelbert von
#
#                                  Leselisten_Rang  Schule_Rang  BDSL_Rang  \
# https://d-nb.info/gnd/118514768              1.0          1.0        1.0
# https://d-nb.info/gnd/118516906              2.0          3.0        6.0
# https://d-nb.info/gnd/118505602              3.0          5.0        4.0
# https://d-nb.info/gnd/118509047              4.0          8.5        9.0
# https://d-nb.info/gnd/118509861              5.0         13.0        5.0
# https://d-nb.info/gnd/118519859              6.0         19.0        3.0
# https://d-nb.info/gnd/118527908              7.0          2.0       13.0
# https://d-nb.info/gnd/118527533              8.0        188.0       14.0
# https://d-nb.info/gnd/118526200              9.0         12.0        7.0
# https://d-nb.info/gnd/118512676             10.0          4.0       11.0
# https://d-nb.info/gnd/118515055             11.0         10.5       15.0
# https://d-nb.info/gnd/118518801             12.0        188.0        8.0
# https://d-nb.info/gnd/118513451             13.0          6.0       34.5
# https://d-nb.info/gnd/118509039             14.0         56.0        2.0
# https://d-nb.info/gnd/118501232             15.0        100.5       20.0
# https://d-nb.info/gnd/118515470             16.0         28.0       26.0
# https://d-nb.info/gnd/118515586             17.0         56.0       68.0
# https://d-nb.info/gnd/118504177             18.0        188.0       17.0
# https://d-nb.info/gnd/118504185             19.0        188.0       18.0
# https://d-nb.info/gnd/118520040             20.0        188.0       27.0
#
#                                  Wiki_Rang
# https://d-nb.info/gnd/118514768        2.0
# https://d-nb.info/gnd/118516906        8.0
# https://d-nb.info/gnd/118505602        1.0
# https://d-nb.info/gnd/118509047       34.0
# https://d-nb.info/gnd/118509861       26.0
# https://d-nb.info/gnd/118519859       32.0
# https://d-nb.info/gnd/118527908       11.0
# https://d-nb.info/gnd/118527533       15.0
# https://d-nb.info/gnd/118526200       45.0
# https://d-nb.info/gnd/118512676       18.0
# https://d-nb.info/gnd/118515055       42.0
# https://d-nb.info/gnd/118518801       47.0
# https://d-nb.info/gnd/118513451       25.0
# https://d-nb.info/gnd/118509039       19.0
# https://d-nb.info/gnd/118501232       67.0
# https://d-nb.info/gnd/118515470      124.0
# https://d-nb.info/gnd/118515586      144.5
# https://d-nb.info/gnd/118504177       74.0
# https://d-nb.info/gnd/118504185       44.0
# https://d-nb.info/gnd/118520040       60.0

# %%
px.bar(
    all_authors.sort_values(by='Leselisten_Anteil').tail(10),
    x = 'GND_Autor',
    y = ['Leselisten_Anteil', 'Schule_Anteil', 'BDSL_Anteil', 'Wiki_Anteil'],
    barmode='group'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2dca7a34-9637-483d-bf55-07e3396021be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dca7a34-9637-483d-bf55-07e3396021be")) {                    Plotly.newPlot(                        "2dca7a34-9637-483d-bf55-07e3396021be",                        [{"alignmentgroup":"True","hovertemplate":"variable=Leselisten_Anteil\u003cbr\u003eGND_Autor=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Leselisten_Anteil","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Leselisten_Anteil","offsetgroup":"Leselisten_Anteil","orientation":"v","showlegend":true,"textposition":"auto","x":["B\u00f6ll, Heinrich","D\u00f6blin, Alfred","Droste-H\u00fclshoff, Annette von","D\u00fcrrenmatt, Friedrich","Celan, Paul","Bernhard, Thomas","Benn, Gottfried","Bachmann, Ingeborg","B\u00fcchner, Georg","Brecht, Bertolt"],"xaxis":"x","y":[0.03620301605564669,0.03660925219003507,0.03686348260696474,0.03707653976820852,0.0422240054432038,0.04918570979898749,0.05482371264392459,0.056094825900508204,0.06762570351143225,0.11842788942048393],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Schule_Anteil\u003cbr\u003eGND_Autor=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Schule_Anteil","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Schule_Anteil","offsetgroup":"Schule_Anteil","orientation":"v","showlegend":true,"textposition":"auto","x":["B\u00f6ll, Heinrich","D\u00f6blin, Alfred","Droste-H\u00fclshoff, Annette von","D\u00fcrrenmatt, Friedrich","Celan, Paul","Bernhard, Thomas","Benn, Gottfried","Bachmann, Ingeborg","B\u00fcchner, Georg","Brecht, Bertolt"],"xaxis":"x","y":[0.04449152542372881,0.01694915254237288,0.0,0.06991525423728813,0.01059322033898305,0.014830508474576272,0.0211864406779661,0.038135593220338986,0.059322033898305086,0.13771186440677965],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=BDSL_Anteil\u003cbr\u003eGND_Autor=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BDSL_Anteil","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BDSL_Anteil","offsetgroup":"BDSL_Anteil","orientation":"v","showlegend":true,"textposition":"auto","x":["B\u00f6ll, Heinrich","D\u00f6blin, Alfred","Droste-H\u00fclshoff, Annette von","D\u00fcrrenmatt, Friedrich","Celan, Paul","Bernhard, Thomas","Benn, Gottfried","Bachmann, Ingeborg","B\u00fcchner, Georg","Brecht, Bertolt"],"xaxis":"x","y":[0.02252391237272447,0.030093592512598993,0.018533374472899312,0.022112516712948678,0.06070142959991772,0.04445130103877404,0.02746066029003394,0.04562377866913504,0.03651136480510131,0.10856731461483081],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Wiki_Anteil\u003cbr\u003eGND_Autor=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wiki_Anteil","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Wiki_Anteil","offsetgroup":"Wiki_Anteil","orientation":"v","showlegend":true,"textposition":"auto","x":["B\u00f6ll, Heinrich","D\u00f6blin, Alfred","Droste-H\u00fclshoff, Annette von","D\u00fcrrenmatt, Friedrich","Celan, Paul","Bernhard, Thomas","Benn, Gottfried","Bachmann, Ingeborg","B\u00fcchner, Georg","Brecht, Bertolt"],"xaxis":"x","y":[0.017408162301986517,0.0059669979577578695,0.018609928621076056,0.02053796715813361,0.010434584382809552,0.012652326453601462,0.00935597002921867,0.04414981184929958,0.02180684626496084,0.042516062886471785],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[ ...

# %%
all_authors[[
    'Leselisten_Summe', 'Schule_Summe', 'BDSL_Summe', 'Wiki_Summe',
    ]].corr(method='pearson')
# Out:
#                   Leselisten_Summe  Schule_Summe  BDSL_Summe  Wiki_Summe
# Leselisten_Summe          1.000000      0.832602    0.863487    0.555381
# Schule_Summe              0.832602      1.000000    0.688283    0.538562
# BDSL_Summe                0.863487      0.688283    1.000000    0.530032
# Wiki_Summe                0.555381      0.538562    0.530032    1.000000
